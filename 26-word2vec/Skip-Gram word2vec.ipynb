# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
#from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6ba3191d89fe> in <module>()
#       8 dataset_name = 'Text8 Dataset'
#       9
# ---> 10 class DLProgress(tqdm):
#      11     last_block = 0
#      12
#
# NameError: name 'tqdm' is not defined

# %%
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
print(int_words[:30])
# Out:
# [5237, 3082, 11, 5, 194, 1, 3135, 45, 58, 155, 127, 741, 476, 10636, 133, 0, 27819, 1, 0, 102, 854, 2, 0, 15107, 60161, 1, 0, 150, 854, 3580]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
random.seed(42)

# %%
def discard_probability(freq, t=1e-5):
    #freq is defined as relative frequency to the corpus f(w) = ct(w)/size_of_corpus
    return max(1 - np.sqrt( t / freq), 0.0)

# %%
def sub_sample(word_list):
    print('Start Counter')
    word_ct = len(word_list)
    word_list_ctr = Counter(word_list)
    print('Finished Counter')
    return [w for w in word_list if (discard_probability(word_list_ctr[w]/word_ct) < random.random() )]


train_words = sub_sample(int_words) # The final subsampled word list

print(len(int_words), len(train_words))
# Out:
# Start Counter
# Finished Counter
# 16680599 4628058

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, window_size + 1) #small fix for window size
    start = max((idx - R), 0) #fix so it doesnt wrap to the left if  R > idx
    end = idx + R
    left, right = words[start:idx], words[(idx + 1):(end + 1)]
    return list(set(left + right))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
batches =  get_batches(train_words, batch_size=10)
x, y = next(batches)
print(len(x))
print(x)
print(y)
# Out:
# 35
# [5237, 5237, 5237, 5237, 3135, 3135, 3135, 10636, 10636, 10636, 10636, 10636, 27819, 27819, 27819, 27819, 854, 854, 854, 854, 15107, 15107, 60161, 60161, 60161, 854, 854, 854, 854, 854, 3580, 3580, 190, 190, 190]
# [27819, 10636, 854, 3135, 27819, 10636, 5237, 15107, 27819, 5237, 854, 3135, 15107, 10636, 854, 3135, 15107, 60161, 27819, 10636, 60161, 854, 15107, 3580, 854, 60161, 15107, 3580, 190, 854, 190, 854, 60161, 3580, 854]

# %%
tf.reset_default_graph()

train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable( tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable( tf.zeros([n_vocab]) ) # create softmax biases here
    
    # Calculate the loss using negative sampling
    #IF SOMETHING DOESNT WORK CHECK HERE
    #CHECK THE ORDERING OF THE EMBEDS AND THE LABELS
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,  embed, labels, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
f = open('checkpoints/test.txt', 'w')
f.close()

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10


start_time = time.time()

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())
    
    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
print('total_elapsed_time', start_time - time.time())
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6329 0.0381 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5551 0.0375 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3882 0.0352 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.4635 0.0372 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.3800 0.0367 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.3624 0.0360 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.3378 0.0372 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.3261 0.0402 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1924 0.0386 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1371 0.0379 sec/batch
# Nearest to these: ufo, servo, sine, gesellschaft, pyrenean, temporal, waited, nucleation,
# Nearest to time: waveguide, fans, enlai, bosnian, dilbert, deposed, farrar, padishah,
# Nearest to and: rout, chair, verte, earthenware, won, november, manzoni, perkin,
# Nearest to new: paddy, gazetteer, microsoft, men, cameo, correct, spyware, maintenance,
# Nearest to system: bottleneck, parrot, isaiah, oates, gamsakhurdia, geneticist, bertie, greens,
# Nearest to people: salvador, hall, oliva, pomeranian, hypertalk, dimitri, romanek, slithy,
# Nearest to no: evil, aristotelian, barium, borda, cursus, illuminator, chorionic, corr,
# Nearest to if: proportionality, replete, skis, particle, washburn, national, camira, advocacy,
# Nearest to older: bevy, octave, dodecanese, unsanitary, black, gotham, whitey, beaver,
# Nearest to professional: flats, scopes, foxx, alhazen, other, wiccans, stretching, nutrient,
# Nearest to marriage: maudslay, gian, twente, ptr, algemeen, recon, expendable, windward,
# Nearest to rise: completely, rosen, proconsular, pia, uppercamelcase, gions, stupidity, kames,
# Nearest to gold: aardvark, browsing, mexica, memorably, teas, atrial, abdicated, bruised,
# Nearest to hit: levinson, ligue, reorganized, cliche, harbour, frontend, cowdery, carducci,
# Nearest to pope: pierson, patel, heavyweight, payloads, washtenaw, sacrilegious, jarama, toe,
# Nearest to engine: broadsword, rmungandr, cryobiology, unfilled, aria, observes, poised, hollywood,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.2019 0.0397 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0349 0.0368 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0413 0.0400 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9429 0.0371 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9050 0.0408 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8663 0.0394 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8751 0.0393 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8715 0.0396 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8498 0.0386 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8457 0.0397 sec/batch
# Nearest to these: ufo, temporal, clp, responses, definability, smallest, ambassador, sine,
# Nearest to time: waveguide, enlai, constitute, academies, farrar, bosnian, patent, rise,
# Nearest to and: chair, november, perkin, rout, february, neon, earthenware, interested,
# Nearest to new: paddy, correct, men, democratic, microsoft, exhibiting, furthest, magdalena,
# Nearest to system: microwave, bottleneck, bifurcation, parrot, adequate, greens, dispensational, summing,
# Nearest to people: hall, defoe, salvador, spartans, debit, assigned, pomeranian, fractions,
# Nearest to no: evil, aristotelian, cursus, uniquely, insular, crimes, barium, inconsistencies,
# Nearest to if: proportionality, particle, gives, advocacy, replete, skis, fringes, deus,
# Nearest to older: octave, gotham, beaver, bevy, unsanitary, enrolled, whitey, dodecanese,
# Nearest to professional: flats, other, scopes, keeps, foxx, alhazen, wifi, knee,
# Nearest to marriage: maudslay, gian, ptr, twente, won, attention, recon, minus,
# Nearest to rise: completely, rosen, pia, international, decarlo, croatia, time, uppercamelcase,
# Nearest to gold: browsing, aardvark, reef, memorably, mexica, teas, ollie, summer,
# Nearest to hit: levinson, quantities, console, reorganized, frontend, ligue, modell, accuracy,
# Nearest to pope: pierson, patel, toe, payloads, heavyweight, washtenaw, sacrilegious, justice,
# Nearest to engine: aria, broadsword, ottawa, enormously, observes, falsely, set, shallower,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8112 0.0389 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8036 0.0370 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8086 0.0374 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.7908 0.0370 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7551 0.0355 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7874 0.0358 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7623 0.0377 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7349 0.0381 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7748 0.0410 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7370 0.0388 sec/batch
# Nearest to these: ufo, temporal, responses, clp, ambassador, nucleation, gesellschaft, waited,
# Nearest to time: waveguide, kasparov, enlai, varnothing, academies, receipt, legally, sculptured,
# Nearest to and: chair, perkin, manzoni, kanji, identifiable, foreword, precarious, gender,
# Nearest to new: democratic, grenada, furthest, metropolis, paddy, busch, spyware, men,
# Nearest to system: microwave, summing, bifurcation, adequate, dispensational, chartist, bottleneck, greens,
# Nearest to people: oliva, mubarak, sitcoms, hall, salvador, spartans, hypertalk, lorenzo,
# Nearest to no: aristotelian, evil, inconsistencies, vauxhall, uniquely, crimes, icp, dubh,
# Nearest to if: proportionality, particle, camira, replete, gives, functors, washburn, bijective,
# Nearest to older: whitey, octave, unsanitary, bevy, dodecanese, median, foraging, exegesis,
# Nearest to professional: flats, scopes, keeps, wifi, alhazen, foxx, denominators, bulls,
# Nearest to marriage: gian, maudslay, twente, zarathustra, ptr, recon, attention, heiress,
# Nearest to rise: rosen, gions, pia, apportionment, completely, wozniak, decarlo, uppercamelcase,
# Nearest to gold: ore, aardvark, peopled, ollie, minerals, memorably, teas, browsing,
# Nearest to hit: levinson, console, frontend, cliche, ligue, urns, archetypical, modell,
# Nearest to pope: pierson, payloads, church, washtenaw, inclusively, toe, eton, patel,
# Nearest to engine: aria, observes, enormously, broadsword, starvation, schwa, cryobiology, showroom,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7501 0.0423 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7424 0.0413 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7021 0.0379 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6932 0.0385 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7187 0.0367 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6636 0.0382 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6964 0.0374 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7270 0.0396 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6310 0.0377 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6319 0.0383 sec/batch
# Nearest to these: temporal, clp, gesellschaft, responses, ufo, nucleation, cayenne, definability,
# Nearest to time: kasparov, waveguide, constitute, infanticide, enlai, varnothing, receipt, wrangler,
# Nearest to and: the, nehru, lsd, koyaanisqatsi, abiogenesis, kanji, stengel, latveria,
# Nearest to new: kamikaze, furthest, democratic, ryde, nemanja, grenada, cedes, metropolis,
# Nearest to system: microwave, adequate, bifurcation, chartist, macrobiotic, fueling, rants, summing,
# Nearest to people: sitcoms, oliva, universalists, pomeranian, hypertalk, deviates, epp, salvador,
# Nearest to no: aristotelian, inconsistencies, evil, uniquely, amdahl, this, vauxhall, same,
# Nearest to if: proportionality, bijective, gives, particle, identity, inherently, describe, countable,
# Nearest to older: median, whitey, unsanitary, bevy, household, octave, dodecanese, versus,
# Nearest to professional: flats, alhazen, playoff, scopes, foxx, clooney, ransomed, wifi,
# Nearest to marriage: maudslay, gian, zarathustra, attention, reconstructionist, alexander, sentiments, twente,
# Nearest to rise: rosen, decarlo, steadfastly, lekhanya, ccj, gions, kames, proconsular,
# Nearest to gold: ore, aardvark, minerals, reef, peopled, summer, mexica, bruised,
# Nearest to hit: modell, frontend, levinson, tamarins, console, cliche, archetypical, ligue,
# Nearest to pope: church, inclusively, king, washtenaw, orthodox, payloads, marie, ascetic,
# Nearest to engine: jet, centrifugal, arithmetics, mach, mechanical, broadsword, aria, enormously,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6506 0.0409 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6213 0.0390 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5442 0.0376 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5757 0.0388 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.5697 0.0393 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5883 0.0385 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5321 0.0299 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5003 0.0382 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4582 0.0393 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4310 0.0385 sec/batch
# Nearest to these: temporal, nyasaland, subjects, gesellschaft, clp, smallest, harmonies, ufo,
# Nearest to time: watercourses, wrangler, enlai, knot, lollapalooza, climatology, prioritize, sunscreen,
# Nearest to and: the, of, in, to, nehru, for, eight, neusner,
# Nearest to new: sgh, kamikaze, cedes, spyware, furthest, moslems, ryde, inseparable,
# Nearest to system: microwave, adequate, monopolistic, aspirant, subroutine, chartist, quickdraw, meantone,
# Nearest to people: sitcoms, archery, pomeranian, hypertalk, universalists, oliva, immortality, deviates,
# Nearest to no: aristotelian, evil, amdahl, uniquely, inconsistencies, nontheism, same, shout,
# Nearest to if: proportionality, countable, gives, decide, inherently, bijective, shrinking, aren,
# Nearest to older: median, household, whitey, versus, bevy, females, unsanitary, exegesis,
# Nearest to professional: bulls, playoff, scopes, alhazen, knee, foxx, flats, ransomed,
# Nearest to marriage: gian, motet, maudslay, acquaintance, makkah, adherents, sentiments, exploitable,
# Nearest to rise: ibook, from, most, guarantor, hartree, pleistocene, ccj, steadfastly,
# Nearest to gold: ore, aardvark, minerals, summer, memorably, citrus, witte, managers,
# Nearest to hit: modell, ball, frontend, tamarins, desperation, metropolitans, league, wingtip,
# Nearest to pope: king, marie, washtenaw, justice, viii, ascetic, ishmael, inclusively,
# Nearest to engine: jet, cylinder, racing, mach, aircraft, erie, mbe, speed,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.3876 0.0405 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4633 0.0389 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3717 0.0383 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4875 0.0371 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4018 0.0394 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4079 0.0365 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3928 0.0372 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3233 0.0396 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3301 0.0398 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3284 0.0408 sec/batch
# Nearest to these: nucleation, temporal, clp, smallest, subjects, gesellschaft, kabaddi, solvents,
# Nearest to time: knot, wrangler, completeness, kasparov, waveguide, climatology, watercourses, rise,
# Nearest to and: the, absinthe, fro, aspartame, of, nehru, to, winwood,
# Nearest to new: sgh, furthest, moslems, era, magdalena, kamikaze, cedes, ryde,
# Nearest to system: microwave, adequate, controlled, aspirant, economy, quickdraw, subroutine, transhumanist,
# Nearest to people: sitcoms, oliva, archery, preventative, saber, hypertalk, spartans, pomeranian,
# Nearest to no: aristotelian, nontheism, same, odd, amdahl, uniquely, evil, inconsistencies,
# Nearest to if: countable, proportionality, bijective, invertible, gives, answer, arithmetical, inherently,
# Nearest to older: household, median, versus, females, age, income, fluffy, males,
# Nearest to professional: other, alhazen, scopes, knee, bulls, flats, foxx, keeps,
# Nearest to marriage: gian, motet, acquaintance, maudslay, sentiments, makkah, reconstructionist, mightily,
# Nearest to rise: ibook, hartree, most, time, completely, greater, steadfastly, from,
# Nearest to gold: ore, aardvark, minerals, copper, summer, teas, managers, marginally,
# Nearest to hit: ball, baseman, batter, pitching, sox, metropolitans, catcher, pitch,
# Nearest to pope: king, cathars, ishmael, marie, washtenaw, chrismation, ascetic, clement,
# Nearest to engine: cylinder, jet, mach, convertible, racing, brake, chow, centrifugal,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3683 0.0411 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3609 0.0388 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3889 0.0386 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3200 0.0400 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3529 0.0398 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4123 0.0367 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3033 0.0400 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3422 0.0414 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3310 0.0411 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3492 0.0379 sec/batch
# Nearest to these: clp, gesellschaft, bessus, nucleation, confirmation, smallest, temporal, subjects,
# Nearest to time: kasparov, dtt, songs, knot, fortitude, bethlen, after, hetzel,
# Nearest to and: the, nehru, of, absinthe, s, one, in, nine,
# Nearest to new: press, kamikaze, edition, sgh, era, vancouver, moslems, mancha,
# Nearest to system: controlled, microwave, aspirant, bifurcation, restriction, transhumanist, adequate, voip,
# Nearest to people: sitcoms, mubarak, oliva, republicanism, hilaire, saber, universalists, pomeranian,
# Nearest to no: aristotelian, odd, perlite, evil, kolingba, amdahl, nontheism, inconsistencies,
# Nearest to if: proportionality, countable, satisfy, identity, decide, arithmetical, invertible, affirming,
# Nearest to older: household, median, females, versus, age, males, children, income,
# Nearest to professional: other, alhazen, scopes, flats, bulls, programmers, poker, kcl,
# Nearest to marriage: heiress, motet, maudslay, misdemeanor, acquaintance, sentiments, gian, reconstructionist,
# Nearest to rise: time, lekhanya, frysl, hartree, apportionment, gions, skara, steadfastly,
# Nearest to gold: ore, aardvark, witte, chamorro, ollie, minerals, tin, bruised,
# Nearest to hit: ball, baseman, batter, modell, wingtip, metropolitans, missed, shutter,
# Nearest to pope: cathars, king, vi, clement, ishmael, but, chrismation, schism,
# Nearest to engine: cylinder, jet, diesel, bhp, combustion, mach, drag, racing,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3604 0.0372 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4000 0.0370 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3376 0.0371 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2639 0.0368 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3583 0.0340 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3148 0.0357 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3860 0.0372 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2935 0.0380 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2903 0.0386 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2891 0.0393 sec/batch
# Nearest to these: clp, nucleation, subjects, descriptor, temporal, foundationalism, gesellschaft, cistern,
# Nearest to time: fortitude, kasparov, after, deposed, academies, waveguide, successive, novgorod,
# Nearest to and: the, of, to, for, s, cookies, in, as,
# Nearest to new: sgh, press, era, moslems, efta, evolution, mandatory, inseparable,
# Nearest to system: microwave, optional, voip, controlled, also, aspirant, arabsat, eldridge,
# Nearest to people: sitcoms, universalists, saber, hilaire, oliva, republicanism, preventative, props,
# Nearest to no: jargon, insubstantial, kolingba, import, duplicate, info, nontheism, sequence,
# Nearest to if: countable, proportionality, identity, decide, invertible, answer, aren, i,
# Nearest to older: household, median, females, versus, age, children, males, householder,
# Nearest to professional: other, scopes, alhazen, esiason, yardbirds, poker, programmers, colleges,
# Nearest to marriage: misdemeanor, heiress, divorce, gian, acquaintance, grandmother, succubus, pornography,
# Nearest to rise: of, most, frysl, lekhanya, greater, time, hartree, lapd,
# Nearest to gold: ore, chamorro, copper, witte, minerals, tin, hessians, ollie,
# Nearest to hit: batter, ball, baseman, inning, wingtip, missed, modell, sox,
# Nearest to pope: cathars, justice, vi, chrismation, king, ishmael, xiii, washtenaw,
# Nearest to engine: cylinder, combustion, engines, diesel, jet, bhp, piston, mechanical,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3313 0.0367 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2867 0.0387 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3652 0.0396 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3022 0.0375 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3858 0.0377 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2690 0.0398 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2717 0.0372 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2853 0.0344 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1675 0.0378 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2600 0.0373 sec/batch
# Nearest to these: gesellschaft, subjects, temporal, nucleation, smallest, descriptor, clp, chirality,
# Nearest to time: minogue, kasparov, after, fortitude, songs, the, knot, waveguide,
# Nearest to and: the, s, of, lesotho, to, cookies, for, also,
# Nearest to new: era, press, hampshire, evolution, moslems, organizes, toronto, microsoft,
# Nearest to system: microwave, controlled, fidonet, voip, arabsat, adequate, guidelines, melanogaster,
# Nearest to people: universalists, sitcoms, props, umbrella, republicanism, deaths, pomeranian, hinduism,
# Nearest to no: duplicate, kolingba, import, sequence, insubstantial, nontheism, jargon, odd,
# Nearest to if: countable, invertible, identity, proportionality, propositional, then, decide, proper,
# Nearest to older: household, median, females, versus, children, age, males, householder,
# Nearest to professional: other, scopes, programmers, kcl, foxx, esiason, yardbirds, poker,
# Nearest to marriage: marriages, divorce, halakha, denominations, reconstructionist, sentiments, relationship, acquaintance,
# Nearest to rise: of, most, vanguard, time, greater, lapd, skara, bondage,
# Nearest to gold: ore, copper, tin, chamorro, witte, keeper, minerals, roo,
# Nearest to hit: missed, wingtip, baseman, modell, ign, tamarins, diamondbacks, rappers,
# Nearest to pope: xiii, vi, justice, poitiers, king, xii, viii, castile,
# Nearest to engine: cylinder, combustion, engines, diesel, jet, mach, bhp, centrifugal,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2619 0.0370 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2422 0.0369 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2532 0.0191 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2121 0.0394 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1531 0.0379 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1985 0.0375 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1648 0.0388 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1436 0.0396 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2240 0.0394 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1413 0.0367 sec/batch
# Nearest to these: auckland, temporal, gesellschaft, yugoslavia, clp, occasionally, nucleation, are,
# Nearest to time: after, minogue, the, clock, s, first, songs, knot,
# Nearest to and: the, of, s, to, in, one, for, from,
# Nearest to new: era, moslems, building, organizes, hampshire, press, selig, grainy,
# Nearest to system: fidonet, although, quickdraw, microwave, relay, arabsat, vlan, coaxial,
# Nearest to people: universalists, deaths, births, sitcoms, mothers, religious, pomeranian, republicanism,
# Nearest to no: duplicate, kolingba, odd, import, jargon, opponent, insubstantial, nontheism,
# Nearest to if: countable, decide, invertible, then, answer, proper, satisfy, doesn,
# Nearest to older: household, median, females, versus, age, children, householder, males,
# Nearest to professional: other, world, ncaa, programmers, scopes, football, packers, kcl,
# Nearest to marriage: marriages, halakha, divorce, heiress, sentiments, acquaintance, gian, reconstructionist,
# Nearest to rise: time, ibook, vanguard, skara, bondage, most, hartree, dpr,
# Nearest to gold: copper, ore, keeper, tin, witte, alloy, chamorro, ollie,
# Nearest to hit: batter, baseman, hits, batting, tamarins, catcher, plate, ball,
# Nearest to pope: vi, xiii, xii, poitiers, patriarch, chrismation, clement, invalid,
# Nearest to engine: cylinder, jet, engines, bhp, combustion, diesel, mach, centrifugal,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2255 0.0378 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1776 0.0391 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1759 0.0383 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1072 0.0358 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1706 0.0365 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1536 0.0357 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1018 0.0368 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1537 0.0381 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1827 0.0357 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1361 0.0378 sec/batch
# Nearest to these: are, gesellschaft, subjects, yugoslavia, temporal, auckland, interacting, elucidated,
# Nearest to time: minogue, after, that, s, processors, up, songs, the,
# Nearest to and: the, to, of, which, s, for, by, from,
# Nearest to new: era, press, moslems, organizes, toronto, edition, hampshire, madison,
# Nearest to system: controlled, clarinet, vlan, aspirant, geneticist, fidonet, territoire, freedb,
# Nearest to people: universalists, deaths, births, preventative, yahweh, sitcoms, mothers, religious,
# Nearest to no: odd, borda, sequence, opponent, that, duplicate, connally, shout,
# Nearest to if: countable, we, satisfy, doesn, proper, invertible, aren, decide,
# Nearest to older: household, median, females, age, versus, children, income, males,
# Nearest to professional: other, ncaa, scopes, programmers, kcl, conectiva, football, federation,
# Nearest to marriage: marriages, divorce, halakha, heiress, grandparents, denominations, spouse, reconstructionist,
# Nearest to rise: processors, birkeland, time, ibook, crystalline, vanguard, skara, pangaea,
# Nearest to gold: copper, ore, tin, keeper, silver, alloy, witte, chamorro,
# Nearest to hit: batter, baseman, rbis, batting, catcher, hits, missed, ball,
# Nearest to pope: xii, vi, xiii, patriarch, chrismation, schism, begs, excommunicated,
# Nearest to engine: cylinder, engines, diesel, jet, bhp, piston, bmw, mach,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1829 0.0394 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2116 0.0388 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1882 0.0377 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1850 0.0374 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1750 0.0372 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1894 0.0356 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2191 0.0394 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1545 0.0364 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1255 0.0390 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1844 0.0387 sec/batch
# Nearest to these: gesellschaft, field, temporal, cistern, are, vigen, clp, sio,
# Nearest to time: s, after, cours, minogue, successive, the, that, clock,
# Nearest to and: the, of, to, s, doraemon, from, which, in,
# Nearest to new: era, moslems, cryonics, fredericton, press, organizes, results, fianna,
# Nearest to system: clarinet, transhumanist, assists, outgoing, geneticist, controlled, economy, systems,
# Nearest to people: sitcoms, universalists, births, deaths, hilaire, contributors, hinduism, mothers,
# Nearest to no: import, jargon, duplicate, info, spool, done, insubstantial, insignificant,
# Nearest to if: doesn, we, countable, you, invertible, don, decide, affirming,
# Nearest to older: household, median, females, age, versus, children, males, householder,
# Nearest to professional: other, programmers, kcl, conectiva, amateur, federation, scopes, yardbirds,
# Nearest to marriage: marriages, divorce, heiress, halakha, grandparents, minus, married, grandmother,
# Nearest to rise: during, time, decarlo, crises, ibook, late, lekhanya, greater,
# Nearest to gold: copper, ore, tin, alloy, silver, tender, keeper, gemstones,
# Nearest to hit: batter, wingtip, kino, hits, strikeouts, tamarins, rbis, shutter,
# Nearest to pope: xiii, vi, xii, nicaea, excommunicated, patriarch, attendance, schism,
# Nearest to engine: cylinder, diesel, engines, bhp, mach, combustion, jet, reciprocating,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2019 0.0413 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1612 0.0400 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1753 0.0355 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1907 0.0379 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1164 0.0380 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1078 0.0358 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1978 0.0357 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1468 0.0392 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2214 0.0389 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2166 0.0403 sec/batch
# Nearest to these: rehearsed, gesellschaft, are, yugoslavia, vigen, descriptor, karate, temporal,
# Nearest to time: after, minogue, s, first, rbi, that, grandson, leni,
# Nearest to and: the, of, for, to, s, as, by, doraemon,
# Nearest to new: york, era, moslems, press, halen, organizes, ever, hampshire,
# Nearest to system: controlled, although, transhumanist, aukrust, arabsat, unicameral, geneticist, microwave,
# Nearest to people: deaths, sitcoms, universalists, alumni, umbrella, hilaire, guant, contributors,
# Nearest to no: import, jargon, duplicate, info, buna, odd, spool, forecasted,
# Nearest to if: doesn, decide, want, affirming, invertible, you, don, we,
# Nearest to older: household, versus, age, median, females, children, householder, males,
# Nearest to professional: programmers, federation, foxx, ncaa, other, kcl, football, scopes,
# Nearest to marriage: marriages, divorce, heiress, married, grandparents, minus, halakha, misdemeanor,
# Nearest to rise: during, imperialist, late, decarlo, vanguard, wars, condensate, time,
# Nearest to gold: copper, ore, alloy, tin, silver, witte, keeper, varitek,
# Nearest to hit: batter, hits, slugging, rbis, wingtip, batting, strikeouts, kino,
# Nearest to pope: xiii, vi, xii, schism, excommunicated, innocent, patriarch, poitiers,
# Nearest to engine: engines, cylinder, mach, combustion, diesel, jet, reciprocating, centrifugal,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2597 0.0381 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1842 0.0375 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1466 0.0379 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1286 0.0356 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0174 0.0360 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1817 0.0382 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1466 0.0384 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1676 0.0375 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2237 0.0058 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1246 0.0364 sec/batch
# Nearest to these: koalas, are, such, kryptonite, temporal, cistern, wycliffe, chara,
# Nearest to time: after, s, the, first, meiosis, gumby, clock, hydrologic,
# Nearest to and: of, the, to, s, for, as, a, from,
# Nearest to new: moslems, york, era, populist, virulence, fredericton, hampshire, formed,
# Nearest to system: although, systems, controlled, aukrust, microwave, quickdraw, arabsat, vlan,
# Nearest to people: deaths, universalists, sitcoms, chiuchow, mao, macanese, contributors, mothers,
# Nearest to no: import, duplicate, jargon, info, odd, daisho, spool, amdahl,
# Nearest to if: doesn, affirming, you, we, invertible, satisfy, be, want,
# Nearest to older: versus, household, median, age, children, income, females, capita,
# Nearest to professional: other, programmers, ncaa, football, amateur, conectiva, coaching, kcl,
# Nearest to marriage: marriages, divorce, marital, heiress, married, minus, remarriage, relationship,
# Nearest to rise: of, lekhanya, during, imperialist, condensate, late, wars, vanguard,
# Nearest to gold: ore, copper, tin, silver, tender, alloy, witte, roo,
# Nearest to hit: hits, batter, rbis, missed, strikeouts, wingtip, slugging, rappers,
# Nearest to pope: xiii, xii, vi, schism, papal, innocent, magnates, eugenius,
# Nearest to engine: engines, cylinder, mach, jet, bhp, exhaust, centrifugal, reciprocating,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0907 0.0394 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1059 0.0378 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0768 0.0397 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0998 0.0370 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0891 0.0379 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0351 0.0371 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1260 0.0389 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0913 0.0372 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1038 0.0387 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0345 0.0402 sec/batch
# Nearest to these: are, koalas, of, such, kryptonite, temporal, occasionally, integrin,
# Nearest to time: s, after, that, the, first, been, this, at,
# Nearest to and: the, of, to, for, from, s, in, a,
# Nearest to new: era, york, moslems, fredericton, hampshire, virulence, results, first,
# Nearest to system: systems, although, controlled, the, also, minister, vlan, quickdraw,
# Nearest to people: deaths, universalists, mao, births, contributors, census, chiuchow, born,
# Nearest to no: duplicate, import, jargon, odd, daisho, requiring, nnhilde, spool,
# Nearest to if: be, doesn, we, affirming, invertible, satisfy, you, either,
# Nearest to older: versus, household, median, age, females, income, capita, children,
# Nearest to professional: other, amateur, federation, programmers, world, tournaments, most, conectiva,
# Nearest to marriage: marriages, divorce, married, heiress, isabelle, marital, minus, isabella,
# Nearest to rise: during, lekhanya, late, time, wars, vanguard, economic, toothfish,
# Nearest to gold: ore, copper, tin, silver, varitek, alloy, roo, molybdenum,
# Nearest to hit: hits, batter, strikeouts, slugging, baseman, bat, sacrifice, runs,
# Nearest to pope: xiii, xii, vi, innocent, patriarch, schism, magnates, papal,
# Nearest to engine: engines, cylinder, jet, mach, exhaust, centrifugal, diesel, bhp,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0607 0.0410 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0587 0.0379 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0182 0.0394 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0787 0.0394 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0960 0.0389 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0545 0.0363 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0833 0.0375 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1363 0.0371 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.1561 0.0367 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0888 0.0356 sec/batch
# Nearest to these: are, such, clp, sio, examples, of, occasionally, temporal,
# Nearest to time: s, after, first, rise, at, this, gumby, clock,
# Nearest to and: of, the, s, by, to, for, in, absinthe,
# Nearest to new: york, press, era, ever, neusner, first, sagan, moslems,
# Nearest to system: systems, of, outgoing, ngl, apocalypses, as, minister, controlled,
# Nearest to people: universalists, alumni, contributors, deaths, mao, births, infant, to,
# Nearest to no: odd, kolingba, import, that, duplicate, requiring, spool, any,
# Nearest to if: doesn, invertible, we, you, satisfy, want, affirming, be,
# Nearest to older: versus, median, household, age, females, income, families, capita,
# Nearest to professional: amateur, programmers, other, conectiva, collegiate, federation, predynastic, certification,
# Nearest to marriage: marriages, divorce, heiress, married, marital, spouse, grandparents, taniyama,
# Nearest to rise: time, adjusted, lekhanya, inflation, condensate, pangaea, during, late,
# Nearest to gold: ore, copper, silver, tin, varitek, tender, molybdenum, keeper,
# Nearest to hit: hits, batter, slugging, rbis, rappers, baseman, batting, plate,
# Nearest to pope: xiii, xii, vi, innocent, schism, magnates, eugenius, papal,
# Nearest to engine: engines, cylinder, diesel, piston, reciprocating, crankshaft, mach, bhp,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.1049 0.0362 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1369 0.0371 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1049 0.0382 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.1199 0.0386 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0698 0.0381 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0505 0.0385 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1044 0.0366 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0729 0.0400 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1208 0.0396 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0529 0.0398 sec/batch
# Nearest to these: are, koalas, such, examples, kryptonite, occasionally, caesarea, haiku,
# Nearest to time: after, s, clock, verdi, godzilla, been, of, first,
# Nearest to and: the, of, s, for, which, to, in, by,
# Nearest to new: york, moslems, era, hampshire, populist, virulence, tico, barnes,
# Nearest to system: systems, outgoing, minister, executive, aspirant, also, unicameral, banteay,
# Nearest to people: universalists, births, deaths, alumni, contributors, mao, population, living,
# Nearest to no: insubstantial, import, info, duplicate, jargon, kolingba, spool, snobol,
# Nearest to if: doesn, invertible, want, you, we, affirming, either, everyone,
# Nearest to older: age, median, household, versus, females, children, income, capita,
# Nearest to professional: amateur, collegiate, other, ncaa, programmers, conectiva, thais, federation,
# Nearest to marriage: marriages, divorce, married, grandparents, heiress, marital, spouse, isabelle,
# Nearest to rise: time, during, lekhanya, ackerman, late, imperialist, ushered, wars,
# Nearest to gold: ore, silver, copper, tin, alloy, varitek, mined, tender,
# Nearest to hit: batter, hits, sacrifice, album, slugging, rbis, missed, rang,
# Nearest to pope: xiii, vi, schism, innocent, xii, magnates, eugenius, boniface,
# Nearest to engine: engines, cylinder, diesel, bhp, cc, crankshaft, reciprocating, piston,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0438 0.0398 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0608 0.0380 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0498 0.0371 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.1109 0.0380 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1092 0.0400 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1789 0.0363 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1623 0.0387 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.1411 0.0402 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0653 0.0402 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.1187 0.0353 sec/batch
# Nearest to these: are, examples, sio, such, impractical, occasionally, pangolins, chara,
# Nearest to time: s, minogue, after, utc, clock, that, first, at,
# Nearest to and: the, for, of, a, in, to, as, s,
# Nearest to new: york, hampshire, vikernes, populist, era, replaced, formed, bluebell,
# Nearest to system: systems, outgoing, also, banteay, aspirant, arabsat, octal, microwave,
# Nearest to people: alumni, deaths, universalists, births, contributors, juggalo, personalities, living,
# Nearest to no: import, duplicate, kolingba, jargon, insubstantial, info, this, odd,
# Nearest to if: we, doesn, invertible, be, you, then, y, a,
# Nearest to older: age, household, versus, median, females, children, capita, income,
# Nearest to professional: amateur, other, most, programmers, federation, krug, certification, conectiva,
# Nearest to marriage: marriages, divorce, grandparents, married, heiress, relationship, marital, spouse,
# Nearest to rise: wars, imperialist, inflation, late, vanguard, ackerman, ushered, lekhanya,
# Nearest to gold: silver, ore, copper, alloy, varitek, tin, medals, mined,
# Nearest to hit: batter, slugging, hits, rbis, rang, fielders, missed, sacrifice,
# Nearest to pope: xiii, vi, schism, xii, eugenius, magnates, innocent, attendance,
# Nearest to engine: engines, cylinder, combustion, centrifugal, diesel, crankshaft, reciprocating, cc,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0132 0.0413 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0624 0.0378 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.1183 0.0394 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0855 0.0399 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1479 0.0387 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.1418 0.0360 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0688 0.0367 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0739 0.0381 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0700 0.0357 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0186 0.0381 sec/batch
# Nearest to these: are, solvents, examples, occasionally, such, some, swivel, of,
# Nearest to time: s, after, the, had, first, at, up, been,
# Nearest to and: the, to, of, for, by, s, as, also,
# Nearest to new: york, moslems, first, vikernes, tico, era, paterson, hampshire,
# Nearest to system: systems, outgoing, the, also, immune, banteay, operating, teleoperation,
# Nearest to people: alumni, living, universalists, births, deaths, americans, contributors, abram,
# Nearest to no: kolingba, import, insubstantial, duplicate, jargon, odd, this, that,
# Nearest to if: we, doesn, affirming, want, be, then, you, that,
# Nearest to older: household, age, versus, median, capita, females, children, income,
# Nearest to professional: amateur, other, programmers, federation, most, ncaa, knee, football,
# Nearest to marriage: marriages, divorce, marital, married, wives, isabella, grandparents, relationship,
# Nearest to rise: wars, imperialist, toothfish, time, kames, ushered, ummah, adjusted,
# Nearest to gold: silver, ore, copper, medals, tin, varitek, polished, alloy,
# Nearest to hit: hits, slugging, rbis, ivb, strikeouts, batter, bats, wingtip,
# Nearest to pope: vi, innocent, xiii, xii, castile, papal, schism, excommunicated,
# Nearest to engine: engines, cylinder, combustion, nozzle, diesel, centrifugal, wheel, bhp,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.1104 0.0412 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.0514 0.0376 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0703 0.0386 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.1063 0.0405 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0916 0.0374 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0686 0.0396 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9403 0.0374 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.0377 0.0380 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9929 0.0389 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0189 0.0356 sec/batch
# Nearest to these: are, of, in, examples, and, some, such, as,
# Nearest to time: after, the, s, to, up, had, that, this,
# Nearest to and: the, for, by, of, to, in, s, as,
# Nearest to new: york, first, a, in, era, of, to, as,
# Nearest to system: systems, also, of, vine, by, the, a, quickdraw,
# Nearest to people: alumni, births, deaths, universalists, living, thousand, americans, infant,
# Nearest to no: any, that, this, insubstantial, import, odd, duplicate, requiring,
# Nearest to if: we, then, doesn, affirming, be, that, want, it,
# Nearest to older: household, age, versus, median, females, income, capita, families,
# Nearest to professional: amateur, other, federation, ncaa, programmers, certification, football, knee,
# Nearest to marriage: marriages, divorce, marital, married, wives, wife, spouse, grandparents,
# Nearest to rise: toothfish, adjusted, imperialist, wars, inflation, relevance, ushered, pangaea,
# Nearest to gold: silver, ore, copper, medals, tin, alloy, varitek, polished,
# Nearest to hit: rbis, hitting, hits, fielders, batter, slugging, jefferson, baseman,
# Nearest to pope: vi, xiii, innocent, xii, papal, castile, magnates, schism,
# Nearest to engine: engines, cylinder, combustion, centrifugal, crankshaft, reciprocating, injector, piston,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0246 0.0373 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0552 0.0357 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0305 0.0401 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0928 0.0388 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0909 0.0378 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.0530 0.0400 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0715 0.0389 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0620 0.0400 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0413 0.0371 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0788 0.0377 sec/batch
# Nearest to these: are, of, in, and, their, such, be, examples,
# Nearest to time: s, after, this, first, to, for, the, had,
# Nearest to and: the, of, s, for, by, to, in, as,
# Nearest to new: york, era, as, cryonics, original, hampshire, virulence, been,
# Nearest to system: systems, extended, computer, multitasking, vine, operating, lines, xemacs,
# Nearest to people: alumni, americans, living, births, native, universalists, nominee, deaths,
# Nearest to no: import, insubstantial, duplicate, jargon, info, done, spool, socket,
# Nearest to if: we, doesn, want, then, affirming, it, that, be,
# Nearest to older: age, household, median, females, children, families, capita, income,
# Nearest to professional: amateur, programmers, other, certified, federation, specific, ncaa, wrestler,
# Nearest to marriage: marriages, divorce, marital, married, wives, marry, spouse, heiress,
# Nearest to rise: imperialist, adjusted, ushered, wars, during, late, lekhanya, inflation,
# Nearest to gold: silver, ore, tin, copper, medals, varitek, defamation, value,
# Nearest to hit: album, remixes, hits, charts, rbis, hitting, jefferson, compilation,
# Nearest to pope: vi, xiii, innocent, xii, magnates, papal, castile, schism,
# Nearest to engine: engines, cylinder, combustion, crankshaft, centrifugal, diesel, piston, reciprocating,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0841 0.0395 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.1029 0.0390 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0270 0.0377 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0736 0.0381 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0657 0.0385 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0536 0.0376 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0261 0.0353 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.0096 0.0356 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0017 0.0392 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.1454 0.0370 sec/batch
# Nearest to these: are, were, many, examples, most, some, several, much,
# Nearest to time: s, first, that, after, this, in, for, been,
# Nearest to and: the, of, in, for, as, s, to, by,
# Nearest to new: york, era, first, in, formed, original, the, dover,
# Nearest to system: systems, also, operating, multitasking, teleoperation, irreducibly, lines, vine,
# Nearest to people: americans, universalists, living, areas, births, deaths, population, native,
# Nearest to no: duplicate, import, jargon, info, snobol, recognise, insubstantial, socket,
# Nearest to if: we, doesn, can, want, then, always, be, that,
# Nearest to older: household, age, families, median, capita, versus, children, females,
# Nearest to professional: federation, amateur, ncaa, programmers, certified, home, certification, conectiva,
# Nearest to marriage: marriages, divorce, marital, married, spouse, marry, wife, wives,
# Nearest to rise: wars, late, imperialist, relevance, during, pleistocene, solidified, ushered,
# Nearest to gold: silver, ore, copper, precious, medals, varitek, alloy, tin,
# Nearest to hit: rbi, hitting, batter, rbis, runs, aaron, hits, slugging,
# Nearest to pope: vi, innocent, xiii, xii, schism, magnates, ordinis, attendance,
# Nearest to engine: engines, cylinder, combustion, crankshaft, centrifugal, reciprocating, piston, nozzle,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.0759 0.0405 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1474 0.0385 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0801 0.0386 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0991 0.0398 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 4.0075 0.0402 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 4.0025 0.0377 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0532 0.0376 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9614 0.0387 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0780 0.0350 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 4.0504 0.0352 sec/batch
# Nearest to these: are, examples, many, groups, some, koalas, were, larp,
# Nearest to time: s, the, was, in, to, and, had, after,
# Nearest to and: the, of, in, for, to, s, a, one,
# Nearest to new: york, first, in, era, hampshire, gosling, dover, when,
# Nearest to system: systems, operating, lines, multitasking, run, although, also, dos,
# Nearest to people: americans, alumni, living, births, millions, universalists, deaths, estimated,
# Nearest to no: import, duplicate, jargon, snobol, major, connally, info, flat,
# Nearest to if: then, we, doesn, invertible, whenever, you, be, get,
# Nearest to older: household, age, versus, families, capita, children, median, females,
# Nearest to professional: amateur, programmers, federation, certified, ncaa, conectiva, krug, certification,
# Nearest to marriage: marriages, divorce, marital, polyandry, spouse, married, remarriage, polygamy,
# Nearest to rise: relevance, okanagan, economic, late, imperialist, adjusted, toothfish, rises,
# Nearest to gold: silver, copper, medals, ore, varitek, olympics, precious, alloy,
# ...
# Nearest to engine: engines, ramjet, jumo, jet, combustion, supercharger, bernoulli, lenoir,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.0521 0.0383 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.8689 0.0406 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.9710 0.0396 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.9406 0.0392 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.9792 0.0378 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.0370 0.0398 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.0158 0.0395 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.9416 0.0403 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9956 0.0400 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.0867 0.0387 sec/batch
# Nearest to these: are, and, some, several, called, they, have, such,
# Nearest to time: this, to, be, for, it, is, by, just,
# Nearest to and: the, to, in, by, with, a, of, for,
# Nearest to new: york, in, s, the, which, its, by, a,
# Nearest to system: systems, use, lines, generally, are, is, both, main,
# Nearest to people: alumni, living, births, americans, all, society, chicagoans, see,
# Nearest to no: insubstantial, duplicate, there, import, any, requiring, out, so,
# Nearest to if: then, be, must, say, not, that, there, everyone,
# Nearest to older: age, household, versus, size, families, capita, enrolled, females,
# Nearest to professional: amateur, wrestling, certification, wrestler, skilled, football, soccer, federation,
# Nearest to marriage: marriages, divorce, marry, spouses, marrying, remarriage, married, spouse,
# Nearest to rise: imperialist, adjusted, during, trend, moreover, rises, the, economic,
# Nearest to gold: medals, silver, olympics, bronze, medalist, plated, value, nickel,
# Nearest to hit: hits, hitting, album, batter, catcher, struck, slugging, rbis,
# Nearest to pope: xiii, innocent, papal, vi, archbishop, papacy, excommunicated, pius,
# Nearest to engine: engines, jumo, ramjet, diesel, camshaft, crankshaft, combustion, cylinder,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.9674 0.0379 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.0012 0.0387 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.0126 0.0392 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.9815 0.0377 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.0323 0.0380 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.0382 0.0383 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.0397 0.0395 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.9996 0.0397 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.0631 0.0373 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9914 0.0382 sec/batch
# Nearest to these: are, and, were, some, they, several, in, of,
# Nearest to time: this, after, first, for, to, period, by, was,
# Nearest to and: the, of, in, as, to, by, with, for,
# Nearest to new: york, s, in, the, and, been, harpercollins, its,
# Nearest to system: systems, the, use, legislature, lines, main, of, in,
# Nearest to people: births, americans, living, alumni, american, society, population, natives,
# Nearest to no: import, insubstantial, info, duplicate, jargon, done, socket, snobol,
# Nearest to if: that, be, then, or, everyone, not, this, some,
# Nearest to older: age, household, versus, decades, families, capita, females, enrolled,
# Nearest to professional: amateur, wrestler, wrestling, certification, soccer, federation, skilled, methamphetamine,
# Nearest to marriage: marriages, divorce, marry, spouses, marrying, married, wife, annulled,
# Nearest to rise: during, moreover, fall, rises, late, levels, last, in,
# Nearest to gold: olympics, silver, medals, ancient, medalist, purple, ore, wax,
# Nearest to hit: album, hits, titled, hitting, charts, released, remixes, chic,
# Nearest to pope: xiii, vi, archbishop, papacy, innocent, papal, elevates, pius,
# Nearest to engine: engines, crankshaft, compressor, ramjet, diesel, combustion, jumo, sedan,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.0196 0.0420 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.9967 0.0396 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.9869 0.0401 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.9484 0.0390 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.1270 0.0395 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.0197 0.0391 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.1252 0.0399 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.0043 0.0391 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.0605 0.0374 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.9878 0.0374 sec/batch
# Nearest to these: are, some, several, they, either, other, were, and,
# Nearest to time: was, to, this, in, period, by, that, after,
# Nearest to and: the, of, by, in, to, also, a, with,
# Nearest to new: york, until, s, also, first, hampshire, in, replaced,
# Nearest to system: systems, lines, main, most, use, also, dynamical, branch,
# Nearest to people: alumni, living, americans, births, deaths, thousands, of, american,
# Nearest to no: import, duplicate, insubstantial, info, jargon, done, snobol, so,
# Nearest to if: then, be, that, must, g, example, is, say,
# Nearest to older: age, household, versus, decades, families, females, capita, enrolled,
# Nearest to professional: wrestler, part, as, wrestling, therefrom, rios, certification, skilled,
# Nearest to marriage: marriages, divorce, marry, marrying, spouses, wife, marital, annulled,
# Nearest to rise: during, late, however, wars, peaked, most, in, growth,
# Nearest to gold: olympics, silver, medals, nickel, copper, krugerrand, medalist, medal,
# Nearest to hit: hits, hitting, album, rbi, slugging, rbis, baseman, worldwide,
# Nearest to pope: papacy, vi, papal, archbishop, elevates, xiii, innocent, pius,
# Nearest to engine: engines, combustion, jet, lenoir, diesel, jumo, compressor, crankshaft,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.9281 0.0399 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.0587 0.0405 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.9825 0.0375 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.0742 0.0359 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.0378 0.0400 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.0403 0.0389 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.1248 0.0196 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.0073 0.0386 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.9944 0.0362 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.0486 0.0356 sec/batch
# Nearest to these: are, some, several, were, either, other, of, many,
# Nearest to time: to, was, this, that, and, the, after, s,
# Nearest to and: the, of, to, by, on, s, with, in,
# Nearest to new: york, and, hampshire, to, independent, ny, s, until,
# Nearest to system: systems, to, branch, through, centralized, with, own, main,
# Nearest to people: alumni, births, living, americans, philosophers, see, natives, all,
# Nearest to no: import, duplicate, there, so, any, have, snobol, info,
# Nearest to if: that, then, be, when, say, must, there, not,
# Nearest to older: age, household, versus, capita, families, enrolled, younger, decades,
# Nearest to professional: amateur, wrestler, skilled, wrestling, addition, therefrom, certification, professionals,
# Nearest to marriage: marriages, divorce, marry, marrying, ceremony, marital, wife, wives,
# Nearest to rise: during, trend, most, moreover, imperialist, late, nisj, adjusted,
# Nearest to gold: medals, olympics, silver, medalist, medal, krugerrand, copper, nickel,
# Nearest to hit: album, hits, rbi, hitting, baseman, rbis, slugging, run,
# Nearest to pope: vi, papal, innocent, pius, papacy, xiii, archbishop, elevates,
# Nearest to engine: engines, jet, camshaft, jumo, sedan, diesel, combustion, injectors,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.0135 0.0402 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.0499 0.0382 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.0596 0.0356 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.0141 0.0371 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.0170 0.0367 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.9703 0.0409 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.0104 0.0411 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.8875 0.0372 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.9819 0.0400 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.9952 0.0385 sec/batch
# Nearest to these: are, of, some, many, and, other, in, they,
# Nearest to time: this, to, that, in, when, it, be, of,
# Nearest to and: the, by, of, to, a, in, is, on,
# Nearest to new: york, of, s, in, the, also, revised, independent,
# Nearest to system: systems, has, only, also, both, by, use, with,
# Nearest to people: americans, births, alumni, see, living, or, of, society,
# Nearest to no: there, duplicate, have, on, so, import, any, are,
# Nearest to if: be, that, then, this, not, say, must, is,
# Nearest to older: age, household, versus, families, below, capita, enrolled, size,
# Nearest to professional: amateur, skilled, professionals, certification, skill, methamphetamine, wrestling, offer,
# Nearest to marriage: marriages, divorce, marry, marital, ceremony, marrying, monogamy, polygamy,
# Nearest to rise: during, moreover, imperialist, late, global, last, levels, wolfgang,
# Nearest to gold: silver, olympics, medals, ore, copper, precious, mining, medalist,
# Nearest to hit: hits, rbi, rbis, runs, batter, hitting, fielder, album,
# Nearest to pope: papal, innocent, elevates, archbishop, pius, xiii, vi, xii,
# Nearest to engine: engines, camshaft, sedan, jumo, jet, combustion, crankshaft, diesel,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.9010 0.0393 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.0056 0.0395 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.0435 0.0396 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.9883 0.0404 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.9942 0.0399 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.0866 0.0381 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.0498 0.0369 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.0184 0.0369 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.0399 0.0400 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.0526 0.0383 sec/batch
# Nearest to these: are, were, of, they, which, by, in, and,
# Nearest to time: that, this, to, when, by, it, is, then,
# Nearest to and: the, of, in, by, to, s, which, with,
# Nearest to new: york, and, of, s, the, in, as, press,
# Nearest to system: systems, main, the, has, however, of, kombinate, use,
# Nearest to people: births, americans, alumni, mathematicians, natives, society, see, politicians,
# Nearest to no: there, have, seven, one, on, of, and, first,
# Nearest to if: must, be, then, not, say, that, either, this,
# Nearest to older: age, versus, below, household, females, families, median, living,
# Nearest to professional: professionals, skilled, amateur, certification, expertise, regulated, certified, wrestler,
# Nearest to marriage: marriages, divorce, marry, marrying, marital, wife, ceremony, spouses,
# Nearest to rise: during, the, of, example, on, moreover, a, led,
# Nearest to gold: silver, medals, olympics, ore, medalist, copper, mining, precious,
# Nearest to hit: hits, album, batter, hitting, charts, charted, rbis, solo,
# Nearest to pope: papal, pius, papacy, xiii, elevates, archbishop, vi, encyclical,
# Nearest to engine: engines, camshaft, combustion, diesel, sedan, jumo, crankshaft, cylinder,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.0579 0.0400 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.0548 0.0404 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.9928 0.0357 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.0021 0.0405 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.0011 0.0401 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.0126 0.0403 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.0167 0.0374 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.0170 0.0371 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.9652 0.0382 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.9796 0.0404 sec/batch
# Nearest to these: are, were, in, many, some, to, they, there,
# Nearest to time: to, that, by, s, first, in, period, for,
# Nearest to and: the, of, to, as, a, for, in, on,
# Nearest to new: york, of, in, the, been, and, several, more,
# Nearest to system: systems, the, main, to, like, only, operating, of,
# Nearest to people: living, births, americans, alumni, society, population, according, thousands,
# Nearest to no: import, insubstantial, duplicate, info, jargon, done, snobol, soundex,
# Nearest to if: then, that, be, say, is, assume, can, get,
# Nearest to older: age, below, household, capita, families, versus, females, poverty,
# Nearest to professional: professionals, amateur, skilled, floorball, wrestling, football, certification, wrestler,
# Nearest to marriage: marriages, marry, divorce, marrying, wife, marital, married, spouses,
# Nearest to rise: during, of, in, a, moreover, late, djamena, global,
# Nearest to gold: silver, medals, medalist, ore, copper, precious, olympics, mining,
# Nearest to hit: runs, hitting, hits, rbi, run, album, rbis, slugging,
# Nearest to pope: papal, bishops, elevates, vi, xiii, papacy, archbishop, innocent,
# Nearest to engine: engines, diesel, camshaft, combustion, crankshaft, jumo, cylinder, centrifugal,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.0699 0.0386 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.0361 0.0388 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.1138 0.0386 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.0374 0.0376 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.0717 0.0354 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.0419 0.0402 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.9854 0.0394 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.9625 0.0407 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.8703 0.0406 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.0724 0.0382 sec/batch
# Nearest to these: some, are, many, they, were, as, several, which,
# Nearest to time: to, the, was, s, with, this, by, in,
# Nearest to and: the, of, to, a, in, also, other, for,
# Nearest to new: york, first, several, in, the, independent, until, last,
# Nearest to system: systems, satellite, only, lines, domestic, main, of, also,
# Nearest to people: americans, alumni, living, births, of, to, deaths, society,
# Nearest to no: insubstantial, import, duplicate, info, jargon, snobol, done, have,
# Nearest to if: then, be, assume, that, say, is, example, there,
# Nearest to older: household, age, below, versus, decades, capita, families, median,
# Nearest to professional: wrestler, wrestling, professionals, skilled, interferons, certification, football, expertise,
# Nearest to marriage: marriages, marry, divorce, marrying, marital, wife, spouses, ceremony,
# Nearest to rise: economic, moreover, during, levels, rises, late, especially, increasing,
# Nearest to gold: silver, medals, medalist, mining, copper, olympics, krugerrand, precious,
# Nearest to hit: hits, album, run, hitting, runs, rbis, worldwide, released,
# Nearest to pope: vi, xiii, innocent, papal, xii, elevates, pius, papacy,
# Nearest to engine: engines, camshaft, centrifugal, combustion, ramjet, diesel, crankshaft, sedan,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.0483 0.0393 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.0607 0.0370 sec/batch
# total_elapsed_time -1782.558338880539

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 600
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
