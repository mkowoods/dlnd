# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
print(int_words[:30])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3135, 45, 58, 155, 127, 741, 476, 10610, 133, 0, 27924, 1, 0, 102, 854, 2, 0, 15102, 61108, 1, 0, 150, 854, 3583]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
random.seed(42)

# %%
def discard_probability(freq, t=1e-5):
    #freq is defined as relative frequency to the corpus f(w) = ct(w)/size_of_corpus
    return max(1 - np.sqrt( t / freq), 0.0)

# %%
def sub_sample(word_list):
    print('Start Counter')
    word_ct = len(word_list)
    word_list_ctr = Counter(word_list)
    print('Finished Counter')
    return [w for w in word_list if (discard_probability(word_list_ctr[w]/word_ct) < random.random() )]


train_words = sub_sample(int_words) # The final subsampled word list

print(len(int_words), len(train_words))
# Out:
# Start Counter
# Finished Counter
# 16680599 4628058

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, window_size)
    left, right = words[(idx-R):idx], words[(idx + 1):(idx + 1 + R)]
    return list(set(left + right))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
batches =  get_batches(train_words, batch_size=10)
x, y = next(batches)
print(len(x))
print(x)
print(y)
# Out:
# 32
# [5233, 5233, 5233, 5233, 3135, 3135, 10610, 10610, 10610, 27924, 27924, 27924, 27924, 854, 854, 854, 854, 15102, 15102, 61108, 61108, 61108, 854, 854, 854, 854, 854, 3583, 3583, 190, 190, 190]
# [10610, 27924, 854, 3135, 10610, 27924, 27924, 15102, 854, 10610, 15102, 854, 3135, 61108, 10610, 27924, 15102, 61108, 854, 15102, 854, 3583, 190, 61108, 15102, 854, 3583, 190, 854, 61108, 854, 3583]

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, 1])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1.0, 1.0)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable( tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable( tf.zeros([n_vocab]) ) # create softmax biases here
    
    # Calculate the loss using negative sampling
    #IF SOMETHING DOESNT WORK CHECK HERE
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10


start_time = time.time()

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())
    
    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
print('total_elapsed_time', start_time - time.time())
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6153 0.0775 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6297 0.0773 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4974 0.0765 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5812 0.0769 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4980 0.0759 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5330 0.0767 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6071 0.0755 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5504 0.0764 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4536 0.0753 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4434 0.0766 sec/batch
# Nearest to may: lumumba, hksar, convoy, crosses, verdeans, hose, icd, glorious,
# Nearest to all: strove, andamans, aqueducts, disguises, coherently, poseidon, joannes, keith,
# Nearest to there: housings, leninism, desiring, commences, gadol, gcb, messier, offends,
# Nearest to history: catalonia, enforces, osteopathic, hallucinogenic, callahan, celebrations, homologous, q,
# Nearest to by: valuing, converge, officer, ayn, ntl, office, gynaecology, zionist,
# Nearest to seven: implanted, oem, waste, jab, yield, remaking, nations, tour,
# Nearest to world: tca, bulb, quivering, amr, entertained, postmaster, lassie, cracow,
# Nearest to more: sibylla, trs, gentle, wombat, eidos, kaufmann, vida, uncanonical,
# Nearest to mainly: accolade, frontispiece, shutter, reabsorption, berber, mcdonough, prescribe, disappointment,
# Nearest to http: shorted, nmi, strumming, cohesion, spears, eldr, trask, escaped,
# Nearest to recorded: housings, computable, mckeon, replenishment, ebla, missiles, desert, polystyrene,
# Nearest to notes: mcdougall, reassure, confusingly, valeria, putty, reduces, dung, frederik,
# Nearest to animals: guilbert, gbc, noodle, longhair, otc, cherished, locust, hizbullah,
# Nearest to hit: upi, oliver, macedonia, cen, mertens, mpr, dessau, celtic,
# Nearest to frac: modernism, relegating, mgf, ruach, anathema, declaring, osvaldo, pounder,
# Nearest to older: nsdap, optimizing, taxing, appleton, ici, honesty, outlets, opposite,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4593 0.0768 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3935 0.0752 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3263 0.0753 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2316 0.0753 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1784 0.0748 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1738 0.0755 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0680 0.0755 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0539 0.0766 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0166 0.0759 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9778 0.0760 sec/batch
# Nearest to may: lumumba, under, convoy, crosses, moreover, icd, holds, glorious,
# Nearest to all: strove, merchant, andamans, disguises, comparable, aqueducts, return, j,
# Nearest to there: only, leninism, housings, converse, bolts, sovereignty, chains, messier,
# Nearest to history: catalonia, celebrations, osteopathic, q, enforces, employed, reason, homologous,
# Nearest to by: converge, office, officer, repeat, valuing, diameter, ayn, assured,
# Nearest to seven: waste, yield, nations, oem, implanted, armed, jab, voltage,
# Nearest to world: tca, bulb, an, entertained, downtown, met, hp, produce,
# Nearest to more: trs, gentle, sibylla, switch, driven, kaufmann, small, reported,
# Nearest to mainly: shutter, prescribe, berber, accolade, mcdonough, disappointment, frontispiece, reabsorption,
# Nearest to http: nmi, shorted, cohesion, strumming, friday, sacrifices, trask, alienate,
# Nearest to recorded: housings, computable, desert, mckeon, red, polystyrene, replenishment, amendments,
# Nearest to notes: mcdougall, area, reduces, track, confusingly, well, which, frederik,
# Nearest to animals: guilbert, otc, noodle, gbc, died, longhair, relieved, cherished,
# Nearest to hit: upi, oliver, macedonia, celtic, dessau, mccormick, our, cen,
# Nearest to frac: modernism, relegating, ruach, anathema, ideologies, hotels, garage, declaring,
# Nearest to older: nsdap, opposite, on, replacing, outlets, optimizing, antonin, lima,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9244 0.0806 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9133 0.0767 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8653 0.0743 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8427 0.0758 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8082 0.0756 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8273 0.0755 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7943 0.0761 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8021 0.0758 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7843 0.0764 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7784 0.0765 sec/batch
# Nearest to may: lumumba, icd, substantiate, moreover, convoy, glorious, holds, verdeans,
# Nearest to all: rumored, strove, andamans, disguises, copyright, aqueducts, poseidon, merchant,
# Nearest to there: leninism, housings, desiring, converse, messier, only, bolts, commences,
# Nearest to history: catalonia, enforces, celebrations, osteopathic, portions, hallucinogenic, homologous, macromolecules,
# Nearest to by: converge, valuing, autonomy, officer, office, ayn, footage, zionist,
# Nearest to seven: waste, clash, armed, nations, implanted, oem, yield, leased,
# Nearest to world: bulb, tca, entertained, tram, hp, downtown, quivering, antwerp,
# Nearest to more: trs, driven, gentle, sibylla, kaufmann, switch, eidos, incidence,
# Nearest to mainly: shutter, prescribe, disappointment, accolade, nash, berber, reabsorption, frontispiece,
# Nearest to http: cohesion, nmi, shorted, friday, strumming, fear, sacrifices, alienate,
# Nearest to recorded: housings, computable, amendments, desert, polystyrene, mckeon, red, missiles,
# Nearest to notes: mcdougall, confusingly, area, frederik, reassure, track, offerings, delta,
# Nearest to animals: guilbert, otc, noodle, gbc, relieved, died, longhair, hizbullah,
# Nearest to hit: oliver, upi, macedonia, celtic, which, shape, dessau, mccormick,
# Nearest to frac: modernism, ruach, declaring, anathema, relegating, hotels, f, dots,
# Nearest to older: nsdap, opposite, optimizing, outlets, throw, replacing, lima, defamation,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7874 0.0774 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7528 0.0769 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7270 0.0793 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7087 0.0773 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7472 0.0789 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7164 0.0792 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7065 0.0758 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7370 0.0785 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7248 0.0764 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6372 0.0759 sec/batch
# Nearest to may: lumumba, substantiate, icd, verdeans, fabricated, moreover, hose, convoy,
# Nearest to all: rumored, strove, andamans, disguises, aqueducts, poseidon, merchant, copyright,
# Nearest to there: leninism, housings, converse, messier, desiring, only, commences, outermost,
# Nearest to history: enforces, catalonia, celebrations, hallucinogenic, osteopathic, homologous, cody, macromolecules,
# Nearest to by: converge, autonomy, officer, zionist, valuing, office, archipelago, hail,
# Nearest to seven: waste, clash, nine, armed, four, fred, nations, jim,
# Nearest to world: bulb, tca, tram, postmaster, indentations, entertained, amr, cracow,
# Nearest to more: trs, driven, sibylla, eidos, vida, gentle, kaufmann, fide,
# Nearest to mainly: reabsorption, accolade, frontispiece, shutter, disappointment, prescribe, leftist, berber,
# Nearest to http: cohesion, nmi, shorted, strumming, trask, alienate, friday, comprehensible,
# Nearest to recorded: housings, computable, amendments, mckeon, missiles, red, desert, declared,
# Nearest to notes: mcdougall, confusingly, area, frederik, cramer, reassure, putty, which,
# Nearest to animals: guilbert, noodle, otc, hizbullah, cherished, gbc, locust, relieved,
# Nearest to hit: upi, oliver, macedonia, dessau, fumes, celtic, which, thorstein,
# Nearest to frac: modernism, f, ruach, dots, anathema, tirith, hotels, seeds,
# Nearest to older: opposite, nsdap, optimizing, outlets, ici, throw, denis, defamation,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6638 0.0775 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6639 0.0759 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6129 0.0764 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6195 0.0765 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6011 0.0768 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6324 0.0763 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5944 0.0552 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5211 0.0775 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5099 0.0772 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4839 0.0759 sec/batch
# Nearest to may: substantiate, lumumba, fabricated, hose, verdeans, icd, moreover, luckily,
# Nearest to all: rumored, andamans, strove, disguises, aqueducts, astrometric, poseidon, battler,
# Nearest to there: leninism, converse, messier, housings, commences, bolts, desiring, outermost,
# Nearest to history: enforces, catalonia, osteopathic, hallucinogenic, celebrations, atolls, cody, macromolecules,
# Nearest to by: converge, officer, valuing, autonomy, zionist, office, hail, gynaecology,
# Nearest to seven: nine, four, clifford, jim, fred, six, bennett, bertil,
# Nearest to world: tram, bulb, postmaster, tca, amr, indentations, impunity, downtown,
# Nearest to more: trs, sibylla, eidos, driven, metrication, incidence, gentle, homelessness,
# Nearest to mainly: frontispiece, reabsorption, nash, accolade, shutter, prescribe, disappointment, leftist,
# Nearest to http: cohesion, nmi, shorted, geocities, html, trask, blueprint, friday,
# Nearest to recorded: housings, computable, amendments, mckeon, weathered, red, missiles, declared,
# Nearest to notes: mcdougall, confusingly, cramer, reassure, frederik, clara, putty, comets,
# Nearest to animals: guilbert, noodle, otc, locust, refreshed, narcotic, hizbullah, relieved,
# Nearest to hit: upi, oliver, fumes, macedonia, cen, dessau, mertens, thorstein,
# Nearest to frac: f, ruach, dots, modernism, dt, mgf, anathema, if,
# Nearest to older: opposite, optimizing, nsdap, ici, outlets, throw, defamation, wrestle,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5043 0.0792 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4967 0.0788 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4592 0.0758 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5358 0.0766 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4839 0.0785 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4611 0.0768 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4248 0.0765 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3781 0.0790 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4256 0.0784 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4214 0.0794 sec/batch
# Nearest to may: fabricated, lumumba, substantiate, verdeans, moreover, hose, loads, specificities,
# Nearest to all: rumored, andamans, disguises, astrometric, strove, aqueducts, statics, functional,
# Nearest to there: converse, leninism, only, bolts, messier, judaizers, commences, outermost,
# Nearest to history: enforces, catalonia, osteopathic, celebrations, atolls, hallucinogenic, ranches, cody,
# Nearest to by: converge, autonomy, officer, zionist, valuing, semitism, hail, assured,
# Nearest to seven: socialite, est, clifford, four, jim, bennett, bertil, clash,
# Nearest to world: tram, postmaster, impunity, bulb, tca, amr, quivering, afro,
# Nearest to more: driven, trs, sibylla, eidos, have, utilize, small, metrication,
# Nearest to mainly: frontispiece, nash, leftist, reabsorption, shutter, berber, accolade, reconciliation,
# Nearest to http: html, www, geocities, htm, nmi, cohesion, acm, ibm,
# Nearest to recorded: housings, computable, red, mckeon, amendments, shouted, naturalization, weathered,
# Nearest to notes: mcdougall, confusingly, cramer, reassure, comets, frederik, clara, fourth,
# Nearest to animals: guilbert, otc, noodle, refreshed, locust, hizbullah, flares, narcotic,
# Nearest to hit: upi, oliver, fumes, undermines, thorstein, mertens, macedonia, cen,
# Nearest to frac: f, continuous, ruach, dt, dots, mgf, if, q,
# Nearest to older: optimizing, opposite, ici, outlets, throw, nsdap, wrestle, antonin,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4364 0.0777 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4215 0.0793 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4183 0.0776 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3996 0.0764 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3952 0.0788 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4621 0.0780 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3993 0.0761 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3832 0.0794 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4036 0.0778 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3806 0.0765 sec/batch
# Nearest to may: fabricated, substantiate, specificities, hose, lumumba, loads, verdeans, moreover,
# Nearest to all: rumored, andamans, astrometric, battler, disguises, statics, aqueducts, functional,
# Nearest to there: converse, messier, only, bolts, satisfy, leninism, desiring, judaizers,
# Nearest to history: enforces, catalonia, osteopathic, celebrations, atolls, cody, ranches, homologous,
# Nearest to by: converge, zionist, confidence, plans, semitism, officer, text, autonomy,
# Nearest to seven: four, est, socialite, clifford, six, nine, bertil, bennett,
# Nearest to world: tram, bulb, postmaster, tca, losers, quivering, impunity, amr,
# Nearest to more: driven, trs, sibylla, eidos, utilize, ect, typically, metrication,
# Nearest to mainly: frontispiece, leftist, reabsorption, berber, nash, shutter, prescribe, reconciliation,
# Nearest to http: html, www, htm, geocities, acm, nmi, ibm, directory,
# Nearest to recorded: housings, computable, red, weathered, naturalization, shouted, qimei, mckeon,
# Nearest to notes: mcdougall, confusingly, cramer, frederik, reassure, putty, clara, rollin,
# Nearest to animals: guilbert, otc, noodle, locust, narcotic, flares, refreshed, burrow,
# Nearest to hit: upi, oliver, fumes, mertens, undermines, thorstein, dream, misdemeanors,
# Nearest to frac: f, dt, continuous, dots, q, n, ruach, mgf,
# Nearest to older: ici, wrestle, outlets, opposite, imparting, optimizing, nsdap, throw,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3667 0.0801 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4075 0.0775 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3715 0.0764 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3333 0.0765 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4108 0.0782 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3392 0.0790 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4031 0.0772 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3764 0.0764 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3169 0.0787 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3385 0.0806 sec/batch
# Nearest to may: substantiate, fabricated, hose, verdeans, specificities, lumumba, moreover, gottfredson,
# Nearest to all: rumored, andamans, astrometric, disguises, battler, statics, strove, assure,
# Nearest to there: converse, messier, only, housings, bolts, desiring, commences, licking,
# Nearest to history: enforces, catalonia, celebrations, osteopathic, atolls, sikh, ranches, one,
# Nearest to by: converge, zionist, semitism, confidence, autonomy, valuing, plans, ntl,
# Nearest to seven: four, est, six, nine, clifford, socialite, zero, heliports,
# Nearest to world: tram, bulb, postmaster, losers, tca, impunity, amr, resettlement,
# Nearest to more: driven, trs, sibylla, ect, eidos, utilize, supplemented, incidence,
# Nearest to mainly: berber, leftist, frontispiece, reabsorption, nash, numidia, feared, camouflaged,
# Nearest to http: www, html, htm, geocities, ibm, directory, acm, nmi,
# Nearest to recorded: housings, computable, weathered, red, shouted, mckeon, futurists, naturalization,
# Nearest to notes: mcdougall, confusingly, cramer, putty, frederik, reassure, rollin, clara,
# Nearest to animals: guilbert, otc, noodle, locust, refreshed, narcotic, blood, flares,
# Nearest to hit: upi, oliver, wembley, fumes, undermines, mertens, run, thorstein,
# Nearest to frac: dt, f, continuous, k, dots, ruach, q, mgf,
# Nearest to older: ici, outlets, imparting, wrestle, throw, opposite, optimizing, balaton,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3447 0.0816 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2864 0.0790 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3520 0.0807 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3513 0.0799 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3934 0.0757 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3033 0.0761 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3136 0.0780 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3529 0.0783 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2419 0.0764 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3103 0.0777 sec/batch
# Nearest to may: substantiate, hose, fabricated, verdeans, specificities, lagrand, gottfredson, kx,
# Nearest to all: rumored, andamans, disguises, astrometric, satrap, strove, statics, battler,
# Nearest to there: converse, messier, only, desiring, housings, satisfy, bolts, equals,
# Nearest to history: enforces, catalonia, celebrations, sikh, atolls, ranches, osteopathic, cody,
# Nearest to by: confidence, converge, zionist, valuing, semitism, isolate, ntl, autonomy,
# Nearest to seven: four, six, nine, est, zero, clifford, socialite, heliports,
# Nearest to world: tram, postmaster, losers, bulb, resettlement, asides, amr, impunity,
# Nearest to more: driven, trs, sibylla, incidence, eidos, ect, swinnerton, learning,
# Nearest to mainly: berber, leftist, reabsorption, frontispiece, feared, numidia, nash, camouflaged,
# Nearest to http: www, html, htm, geocities, directory, acm, edu, ibm,
# Nearest to recorded: housings, weathered, red, computable, shouted, futurists, rock, vandalised,
# Nearest to notes: mcdougall, confusingly, cramer, frederik, putty, clara, metrolink, reassure,
# Nearest to animals: guilbert, otc, noodle, locust, predators, refreshed, burrow, barley,
# Nearest to hit: upi, wembley, oliver, mertens, run, fumes, dream, mandolins,
# Nearest to frac: dt, f, continuous, q, dots, ruach, multiply, constant,
# Nearest to older: wrestle, imparting, ici, opposite, outlets, antonin, optimizing, throw,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2936 0.0800 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2972 0.0768 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3567 0.0340 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2516 0.0779 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2160 0.0791 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2043 0.0764 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2167 0.0769 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2167 0.0792 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2195 0.0774 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1579 0.0758 sec/batch
# Nearest to may: hose, fabricated, substantiate, verdeans, specificities, gottfredson, lagrand, kx,
# Nearest to all: rumored, andamans, disguises, astrometric, strove, satrap, statics, lusitania,
# Nearest to there: converse, messier, desiring, only, bolts, satisfy, housings, sado,
# Nearest to history: enforces, catalonia, celebrations, leonard, atolls, sikh, osteopathic, ranches,
# Nearest to by: zionist, semitism, converge, valuing, confidence, plans, autonomy, ntl,
# Nearest to seven: four, six, nine, clifford, est, zero, one, socialite,
# Nearest to world: tram, postmaster, losers, resettlement, amr, an, bulb, harmattan,
# Nearest to more: driven, trs, sibylla, eidos, metrication, supplemented, utilize, small,
# Nearest to mainly: berber, leftist, reabsorption, feared, numidia, nash, camouflaged, frontispiece,
# Nearest to http: www, htm, html, geocities, edu, directory, acm, org,
# Nearest to recorded: housings, weathered, sow, computable, red, songs, celebrations, shouted,
# Nearest to notes: mcdougall, confusingly, cramer, note, piccolo, frederik, metrolink, clara,
# Nearest to animals: guilbert, noodle, otc, predators, locust, burrow, refreshed, died,
# Nearest to hit: upi, wembley, oval, run, throws, reached, mertens, fumes,
# Nearest to frac: dt, f, mgf, dots, continuous, q, ruach, constant,
# Nearest to older: ici, wrestle, imparting, median, families, mycological, outlets, optimizing,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2564 0.0797 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2414 0.0781 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2114 0.0759 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1385 0.0773 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1564 0.0796 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1861 0.0776 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1686 0.0769 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1653 0.0790 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1894 0.0768 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1728 0.0765 sec/batch
# Nearest to may: fabricated, hose, substantiate, specificities, verdeans, gottfredson, loads, lagrand,
# Nearest to all: rumored, astrometric, disguises, andamans, statics, assure, constructivist, duplex,
# Nearest to there: converse, bolts, messier, desiring, satisfy, only, equals, infinities,
# Nearest to history: enforces, catalonia, celebrations, leonard, homologous, scarves, https, atolls,
# Nearest to by: converge, zionist, valuing, confidence, semiology, ntl, thus, plans,
# Nearest to seven: four, six, est, zero, nine, clifford, socialite, heliports,
# Nearest to world: losers, resettlement, postmaster, tram, bulb, tca, an, quivering,
# Nearest to more: driven, sibylla, trs, eidos, metrication, learning, supplemented, small,
# Nearest to mainly: berber, leftist, nash, reabsorption, numidia, camouflaged, shutter, feared,
# Nearest to http: www, htm, html, geocities, edu, directory, acm, org,
# Nearest to recorded: housings, weathered, rock, songs, sow, red, celebrations, cozy,
# Nearest to notes: mcdougall, confusingly, piccolo, cramer, note, metrolink, eastwood, frederik,
# Nearest to animals: guilbert, noodle, predators, otc, died, locust, refreshed, burrow,
# Nearest to hit: upi, wembley, run, throws, oval, reached, mertens, punch,
# Nearest to frac: dt, f, continuous, mgf, constant, dots, q, k,
# Nearest to older: families, ici, median, wrestle, imparting, males, outlets, mycological,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1673 0.0788 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2461 0.0762 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1475 0.0791 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1639 0.0791 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1974 0.0778 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1736 0.0781 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2177 0.0791 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1826 0.0787 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1472 0.0771 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1871 0.0779 sec/batch
# Nearest to may: fabricated, substantiate, hose, specificities, verdeans, kx, cauchy, lagrand,
# Nearest to all: rumored, assure, astrometric, disguises, statics, andamans, constructivist, prophesying,
# Nearest to there: converse, messier, equals, only, desiring, satisfy, infinities, sado,
# Nearest to history: enforces, leonard, catalonia, celebrations, zork, scarves, sweden, playground,
# Nearest to by: converge, zionist, confidence, ntl, semitism, thus, the, valuing,
# Nearest to seven: four, six, nine, zero, est, clifford, one, eight,
# Nearest to world: losers, resettlement, tram, postmaster, quivering, bulb, an, casablanca,
# Nearest to more: driven, trs, sibylla, eidos, learning, metrication, supplemented, have,
# Nearest to mainly: berber, leftist, numidia, reabsorption, nash, camouflaged, feared, doubling,
# Nearest to http: www, htm, html, geocities, edu, directory, acm, org,
# Nearest to recorded: housings, weathered, rock, songs, sow, numismatic, cozy, shouted,
# Nearest to notes: mcdougall, confusingly, piccolo, cramer, note, frederik, zweig, clara,
# Nearest to animals: guilbert, noodle, predators, otc, locust, burrow, died, refreshed,
# Nearest to hit: upi, wembley, throws, oval, run, reached, mertens, punch,
# Nearest to frac: dt, constant, continuous, mgf, multiply, dots, cdot, q,
# Nearest to older: families, median, ici, wrestle, imparting, householder, males, outlets,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2299 0.0798 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1738 0.0784 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1883 0.0766 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1622 0.0786 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1505 0.0794 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1306 0.0775 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1728 0.0766 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1404 0.0772 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2021 0.0787 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2005 0.0780 sec/batch
# Nearest to may: substantiate, fabricated, verdeans, hose, gottfredson, lagrand, pimp, kx,
# Nearest to all: rumored, disguises, constructivist, prophesying, assure, astrometric, coherently, andamans,
# Nearest to there: converse, messier, housings, desiring, sado, only, bolts, infinities,
# Nearest to history: enforces, catalonia, leonard, sweden, celebrations, zork, homologous, cultural,
# Nearest to by: the, zionist, confidence, semitism, valuing, thus, converge, ntl,
# Nearest to seven: four, six, nine, zero, one, eight, two, five,
# Nearest to world: losers, resettlement, postmaster, asides, jerzy, an, tram, koestler,
# Nearest to more: driven, sibylla, trs, supplemented, racquet, eidos, learning, duvalier,
# Nearest to mainly: berber, leftist, numidia, feared, camouflaged, reabsorption, doubling, nash,
# Nearest to http: www, htm, html, geocities, edu, directory, acm, org,
# Nearest to recorded: housings, weathered, rock, sow, songs, celebrations, lullaby, qimei,
# Nearest to notes: mcdougall, confusingly, piccolo, note, area, clara, cramer, frederik,
# Nearest to animals: predators, guilbert, noodle, otc, locust, burrow, refreshed, died,
# Nearest to hit: wembley, upi, oval, run, throws, mertens, reached, punch,
# Nearest to frac: dt, continuous, dots, mgf, cdot, multiply, constant, ruach,
# Nearest to older: families, median, ici, householder, males, wrestle, imparting, gouvernement,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2384 0.0785 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1515 0.0759 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1489 0.0777 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1292 0.0769 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0545 0.0763 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1365 0.0764 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1462 0.0791 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1151 0.0784 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1877 0.0127 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1337 0.0791 sec/batch
# Nearest to may: fabricated, substantiate, hose, kx, specificities, verdeans, untreated, cauchy,
# Nearest to all: rumored, astrometric, assure, disguises, constructivist, thronged, coherently, hairstyle,
# Nearest to there: messier, converse, housings, sado, bolts, desiring, only, infinities,
# Nearest to history: enforces, catalonia, leonard, zork, sweden, homologous, celebrations, macromolecules,
# Nearest to by: the, thus, ntl, converge, confidence, zionist, semitism, valuing,
# Nearest to seven: four, nine, six, zero, one, eight, two, five,
# Nearest to world: losers, resettlement, postmaster, koestler, an, tram, jerzy, soho,
# Nearest to more: driven, trs, sibylla, supplemented, eidos, small, metrication, hardly,
# Nearest to mainly: berber, leftist, numidia, camouflaged, reabsorption, doubling, feared, shutter,
# Nearest to http: www, htm, html, geocities, edu, org, directory, php,
# Nearest to recorded: housings, weathered, songs, rock, sow, celebrations, lullaby, minuit,
# Nearest to notes: mcdougall, confusingly, piccolo, note, clara, metrolink, frederik, area,
# Nearest to animals: guilbert, predators, noodle, burrow, locust, otc, refreshed, died,
# Nearest to hit: wembley, upi, oval, throws, run, mandolins, reached, punch,
# Nearest to frac: dt, mgf, constant, continuous, observable, cdot, dots, multiply,
# Nearest to older: families, median, ici, householder, imparting, wrestle, males, gouvernement,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0595 0.0787 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0820 0.0760 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0501 0.0765 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0525 0.0772 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0923 0.0761 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0576 0.0777 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0896 0.0782 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1079 0.0764 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1175 0.0788 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0648 0.0784 sec/batch
# Nearest to may: kx, fabricated, hose, specificities, substantiate, untreated, verdeans, riba,
# Nearest to all: rumored, astrometric, disguises, assure, constructivist, hairstyle, coherently, styx,
# Nearest to there: converse, messier, only, bolts, desiring, housings, infinities, vidarbha,
# Nearest to history: leonard, catalonia, enforces, imc, celebrations, sweden, zork, https,
# Nearest to by: the, confidence, converge, semitism, valuing, thus, zionist, of,
# Nearest to seven: four, nine, six, zero, two, one, five, est,
# Nearest to world: losers, postmaster, resettlement, jerzy, casablanca, koestler, tram, custodians,
# Nearest to more: driven, trs, supplemented, small, sibylla, racquet, reducing, learning,
# Nearest to mainly: berber, leftist, doubling, numidia, camouflaged, nash, cropping, reabsorption,
# Nearest to http: www, htm, html, geocities, edu, php, org, acm,
# Nearest to recorded: housings, songs, sow, weathered, rock, celebrations, numismatic, vandalised,
# Nearest to notes: mcdougall, piccolo, confusingly, note, clara, pe, metrolink, deke,
# Nearest to animals: guilbert, predators, burrow, noodle, locust, otc, seductress, refreshed,
# Nearest to hit: upi, reached, wembley, oval, run, throws, mandolins, promo,
# Nearest to frac: dt, mgf, constant, continuous, cdot, algebraically, multiply, conjugate,
# Nearest to older: families, householder, median, ici, males, imparting, females, wrestle,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0394 0.0776 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0152 0.0769 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0080 0.0763 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0616 0.0779 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0817 0.0794 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0734 0.0772 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0568 0.0745 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0739 0.0742 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.1008 0.0741 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0415 0.0739 sec/batch
# Nearest to may: kx, substantiate, fabricated, specificities, hose, untreated, verdeans, cauchy,
# Nearest to all: rumored, astrometric, disguises, assure, associative, constructivist, styx, duplex,
# Nearest to there: converse, messier, only, infinities, desiring, satisfy, invariably, equals,
# Nearest to history: zork, enforces, leonard, homologous, imc, catalonia, encyclopedia, celebrations,
# Nearest to by: the, converge, confidence, thus, zionist, ntl, valuing, of,
# Nearest to seven: four, six, nine, zero, one, est, three, five,
# Nearest to world: losers, jerzy, casablanca, postmaster, koestler, resettlement, quivering, tca,
# Nearest to more: driven, supplemented, trs, learning, sibylla, small, always, have,
# Nearest to mainly: berber, doubling, leftist, camouflaged, numidia, nash, reabsorption, shutter,
# Nearest to http: www, htm, html, geocities, edu, php, org, acm,
# Nearest to recorded: housings, songs, sow, weathered, rock, celebrations, remixed, numismatic,
# Nearest to notes: mcdougall, piccolo, confusingly, note, pe, clara, ayurveda, metrolink,
# Nearest to animals: guilbert, predators, burrow, locust, noodle, otc, refreshed, seductress,
# Nearest to hit: reached, upi, wembley, throws, oval, run, mandolins, promo,
# Nearest to frac: dt, constant, mgf, continuous, multiply, algebraically, dots, right,
# Nearest to older: families, median, householder, ici, females, age, males, imparting,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0736 0.0756 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0774 0.0743 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0680 0.0742 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0718 0.0739 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0604 0.0743 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0143 0.0749 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0616 0.0743 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0989 0.0749 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0995 0.0742 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0575 0.0755 sec/batch
# Nearest to may: substantiate, kx, specificities, fabricated, verdeans, hose, untreated, gottfredson,
# Nearest to all: rumored, astrometric, assure, associative, disguises, madhyamika, constructivist, multivectors,
# Nearest to there: converse, messier, infinities, invariably, desiring, only, vidarbha, sado,
# Nearest to history: zork, encyclopedia, catalonia, cultural, celebrations, enforces, leonard, sweden,
# Nearest to by: the, confidence, thus, of, zionist, confessor, persia, converge,
# Nearest to seven: four, six, nine, zero, one, two, five, est,
# Nearest to world: losers, resettlement, postmaster, casablanca, koestler, jerzy, custodians, an,
# Nearest to more: driven, trs, supplemented, sibylla, racquet, learning, microeconomics, prelude,
# Nearest to mainly: berber, doubling, numidia, leftist, camouflaged, unproductive, reconciliation, nash,
# Nearest to http: www, htm, html, geocities, edu, php, org, acm,
# Nearest to recorded: songs, housings, sow, weathered, rock, lullaby, celebrations, remixed,
# Nearest to notes: mcdougall, piccolo, confusingly, note, pe, clara, ayurveda, frederik,
# Nearest to animals: predators, guilbert, burrow, locust, otc, noodle, refreshed, mammals,
# Nearest to hit: reached, upi, wembley, throws, oval, promo, mandolins, mertens,
# Nearest to frac: dt, mgf, constant, multiply, dots, q, continuous, ddot,
# Nearest to older: families, householder, median, ici, males, age, females, imparting,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0541 0.0766 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0337 0.0734 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0447 0.0731 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0898 0.0747 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0599 0.0749 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1209 0.0741 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1249 0.0712 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0671 0.0722 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0550 0.0722 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0516 0.0715 sec/batch
# Nearest to may: kx, substantiate, fabricated, verdeans, untreated, nucleophile, hose, cauchy,
# Nearest to all: rumored, astrometric, disguises, assure, associative, radek, plus, duplex,
# Nearest to there: converse, infinities, messier, invariably, housings, desiring, vidarbha, bolts,
# Nearest to history: zork, leonard, celebrations, encyclopedia, enforces, homologous, tugboat, playground,
# Nearest to by: the, of, thus, as, confidence, converge, ntl, zionist,
# Nearest to seven: four, six, nine, zero, two, one, five, eight,
# Nearest to world: losers, resettlement, koestler, casablanca, postmaster, jerzy, an, custodians,
# Nearest to more: driven, trs, supplemented, small, tegea, sibylla, learning, have,
# Nearest to mainly: berber, leftist, doubling, numidia, unproductive, camouflaged, balinese, followed,
# Nearest to http: htm, www, html, geocities, edu, php, org, shtml,
# Nearest to recorded: songs, housings, sow, rock, weathered, lullaby, celebrations, flo,
# Nearest to notes: mcdougall, piccolo, confusingly, note, pe, clara, frederik, ayurveda,
# Nearest to animals: predators, locust, guilbert, burrow, noodle, otc, refreshed, seductress,
# Nearest to hit: reached, wembley, upi, promo, oval, throws, mandolins, mertens,
# Nearest to frac: dt, mgf, constant, ddot, multiply, right, dots, observable,
# Nearest to older: families, householder, median, males, ici, females, age, imparting,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9908 0.0728 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0588 0.0718 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0268 0.0715 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0342 0.0718 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0822 0.0721 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0362 0.0637 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0098 0.0730 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9964 0.0742 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0122 0.0747 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9826 0.0749 sec/batch
# Nearest to may: kx, untreated, fabricated, substantiate, hose, nucleophile, specificities, textured,
# Nearest to all: rumored, disguises, astrometric, prophesying, assure, ucmp, multivectors, madhyamika,
# Nearest to there: converse, infinities, messier, invariably, ingham, bolts, housings, desiring,
# Nearest to history: zork, leonard, encyclopedia, celebrations, homologous, playground, cultural, enforces,
# Nearest to by: the, of, thus, confessor, persia, ntl, zionist, semiology,
# Nearest to seven: four, nine, six, one, zero, two, eight, three,
# Nearest to world: losers, jerzy, resettlement, koestler, casablanca, postmaster, custodians, afro,
# Nearest to more: driven, supplemented, trs, small, learning, racquet, grammar, eidos,
# Nearest to mainly: berber, numidia, doubling, leftist, camouflaged, balinese, cropping, unproductive,
# Nearest to http: www, htm, html, geocities, edu, org, php, site,
# Nearest to recorded: songs, housings, sow, weathered, rock, celebrations, country, lullaby,
# Nearest to notes: mcdougall, piccolo, confusingly, note, pe, clara, capella, area,
# Nearest to animals: guilbert, locust, burrow, predators, noodle, otc, refreshed, seductress,
# Nearest to hit: reached, upi, mandolins, promo, oval, wembley, throws, grossing,
# Nearest to frac: dt, mgf, constant, ddot, multiply, ruach, observable, cdot,
# Nearest to older: families, householder, median, ici, age, females, males, imparting,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9722 0.0751 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9526 0.0746 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0102 0.0749 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0104 0.0748 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0474 0.0742 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0118 0.0741 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9332 0.0747 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9665 0.0746 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9440 0.0743 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9732 0.0746 sec/batch
# Nearest to may: kx, fabricated, specificities, untreated, hose, substantiate, nucleophile, delayed,
# Nearest to all: rumored, astrometric, disguises, morphisms, duplex, assure, associative, remaining,
# Nearest to there: converse, infinities, invariably, messier, bolts, desiring, exists, only,
# Nearest to history: zork, encyclopedia, enforces, leonard, homologous, https, celebrations, disambiguation,
# Nearest to by: the, thus, of, as, converge, persia, confidence, confessor,
# Nearest to seven: four, nine, six, zero, two, one, eight, three,
# Nearest to world: losers, resettlement, casablanca, jerzy, koestler, custodians, postmaster, reliance,
# Nearest to more: driven, small, trs, supplemented, kora, have, powerboat, portable,
# Nearest to mainly: berber, leftist, doubling, balinese, cropping, camouflaged, unproductive, numidia,
# Nearest to http: www, htm, html, geocities, org, edu, php, https,
# Nearest to recorded: songs, housings, sow, weathered, rock, country, celebrations, unvoiced,
# Nearest to notes: mcdougall, piccolo, confusingly, note, clara, capella, pe, flicker,
# Nearest to animals: predators, guilbert, locust, burrow, noodle, otc, refreshed, appendages,
# Nearest to hit: reached, wembley, promo, oval, throws, run, upi, mandolins,
# Nearest to frac: dt, mgf, constant, ddot, multiply, cdot, continuous, ruach,
# Nearest to older: families, householder, median, age, females, males, someone, ici,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0023 0.0758 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0240 0.0750 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9720 0.0746 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0214 0.0747 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0278 0.0742 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9611 0.0746 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0077 0.0742 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9926 0.0744 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9898 0.0748 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0058 0.0742 sec/batch
# Nearest to may: kx, substantiate, specificities, fabricated, nucleophile, untreated, types, textured,
# Nearest to all: rumored, astrometric, associative, disguises, assure, morphisms, constructivist, synergy,
# Nearest to there: infinities, converse, desiring, invariably, satisfy, only, brassicaceae, bolts,
# Nearest to history: zork, leonard, encyclopedia, enforces, celebrations, playground, disambiguation, caxton,
# Nearest to by: the, of, thus, confessor, as, confidence, bracelet, henderson,
# Nearest to seven: nine, four, six, one, eight, zero, two, five,
# Nearest to world: losers, jerzy, casablanca, resettlement, koestler, custodians, postmaster, biographie,
# Nearest to more: driven, trs, supplemented, grammar, small, utilize, kora, have,
# Nearest to mainly: berber, leftist, doubling, balinese, camouflaged, cropping, unproductive, aristocracy,
# Nearest to http: www, htm, html, geocities, org, edu, php, shtml,
# Nearest to recorded: songs, housings, sow, rock, weathered, country, lullaby, stealth,
# Nearest to notes: mcdougall, piccolo, note, confusingly, clara, capella, frederik, ayurveda,
# Nearest to animals: locust, predators, guilbert, burrow, noodle, elephants, otc, mammals,
# Nearest to hit: reached, promo, upi, wembley, grossing, mandolins, throws, oval,
# Nearest to frac: dt, mgf, constant, ddot, right, left, multiply, q,
# Nearest to older: families, householder, median, age, females, males, someone, ici,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0191 0.0739 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9999 0.0743 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9995 0.0739 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9853 0.0746 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0297 0.0748 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9909 0.0743 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9966 0.0749 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9717 0.0747 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9664 0.0748 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0253 0.0753 sec/batch
# Nearest to may: kx, substantiate, untreated, indemnity, technicality, gottfredson, pseudo, fabricated,
# Nearest to all: rumored, astrometric, associative, morphisms, assure, multivectors, plus, disguises,
# Nearest to there: converse, infinities, invariably, only, brassicaceae, delimit, desiring, vocalic,
# Nearest to history: zork, encyclopedia, leonard, disambiguation, chronology, harappa, playground, enforces,
# Nearest to by: the, of, thus, as, confessor, persia, zionist, and,
# Nearest to seven: four, nine, six, zero, one, two, eight, five,
# Nearest to world: losers, jerzy, resettlement, casablanca, koestler, postmaster, custodians, agreeing,
# Nearest to more: driven, supplemented, trs, have, racquet, small, microeconomics, mesaoria,
# Nearest to mainly: berber, leftist, balinese, doubling, numidia, aristocracy, unproductive, followed,
# Nearest to http: www, htm, html, geocities, org, edu, php, shtml,
# Nearest to recorded: songs, housings, sow, weathered, rock, country, lullaby, omit,
# Nearest to notes: mcdougall, piccolo, note, confusingly, clara, capella, pe, atwood,
# Nearest to animals: locust, predators, guilbert, burrow, noodle, otc, elephants, unicellular,
# Nearest to hit: reached, promo, wembley, oval, grossing, throws, mandolins, run,
# Nearest to frac: dt, mgf, constant, ddot, left, right, log, ruach,
# Nearest to older: families, householder, median, age, females, ici, someone, males,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9749 0.0758 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0770 0.0747 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0343 0.0750 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0407 0.0739 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9539 0.0744 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9346 0.0746 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0124 0.0745 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9182 0.0743 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9887 0.0740 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9527 0.0743 sec/batch
# Nearest to may: kx, untreated, delayed, riba, substantiate, pimp, technicality, kp,
# Nearest to all: rumored, astrometric, morphisms, associative, assure, plus, disguises, radek,
# Nearest to there: converse, infinities, invariably, bolts, snowshoe, brassicaceae, delimit, if,
# Nearest to history: zork, disambiguation, celebrations, encyclopedia, leonard, harappa, enforces, tugboat,
# Nearest to by: the, of, as, thus, and, bracelet, confessor, for,
# Nearest to seven: nine, four, six, zero, two, one, eight, five,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8676 0.0741 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8300 0.0747 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8664 0.0743 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9227 0.0735 sec/batch
# Nearest to may: usually, remaining, textured, frozen, fiqh, this, example, sedatives,
# Nearest to all: of, there, are, remaining, plus, morphisms, only, multivectors,
# Nearest to there: all, if, might, every, converse, at, is, are,
# Nearest to history: see, zork, encyclopedia, historical, disambiguation, one, article, millennia,
# Nearest to by: the, of, in, and, as, for, an, to,
# Nearest to seven: four, nine, six, one, two, three, eight, five,
# Nearest to world: jerzy, exhibition, losers, history, unaids, biographie, koestler, premillennialism,
# Nearest to more: than, and, many, stronger, have, as, an, mostly,
# Nearest to mainly: seeker, followed, berber, reconciliation, coaching, doubling, protestant, operate,
# Nearest to http: www, htm, geocities, html, org, edu, shtml, php,
# Nearest to recorded: songs, recording, housings, compilation, sow, tennant, country, stereo,
# Nearest to notes: mcdougall, note, piccolo, atwood, confusingly, macmillan, malvinas, fingered,
# Nearest to animals: animal, locust, swarms, guilbert, predators, landholdings, seductress, cartier,
# Nearest to hit: reached, hits, promo, run, grossing, costanza, octopuses, dp,
# Nearest to frac: constant, dt, mgf, ddot, corum, left, osten, vdash,
# Nearest to older: age, families, median, householder, someone, females, below, males,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8198 0.0756 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8339 0.0742 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8579 0.0745 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8784 0.0746 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8664 0.0745 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8779 0.0746 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8852 0.0747 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8306 0.0746 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8835 0.0739 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8518 0.0749 sec/batch
# Nearest to may: textured, usually, frozen, remaining, mycologists, desecration, april, fiqh,
# Nearest to all: there, are, of, remaining, multivectors, only, plus, morphisms,
# Nearest to there: all, varro, are, hanifa, might, converse, exists, only,
# Nearest to history: see, historical, encyclopedia, disambiguation, zork, one, millennia, the,
# Nearest to by: the, of, in, as, and, for, an, thus,
# Nearest to seven: nine, four, six, one, two, eight, three, five,
# Nearest to world: jerzy, exhibition, losers, factbook, unaids, premillennialism, casablanca, koestler,
# Nearest to more: than, many, and, an, stronger, mostly, have, as,
# Nearest to mainly: followed, reconciliation, berber, coaching, protestant, seeker, conformal, aristocracy,
# Nearest to http: www, htm, geocities, html, edu, org, php, shtml,
# Nearest to recorded: songs, compilation, tennant, recording, sow, july, billions, housings,
# Nearest to notes: mcdougall, note, piccolo, macmillan, atwood, confusingly, malvinas, capella,
# Nearest to animals: animal, locust, swarms, guilbert, seductress, predators, elephants, landholdings,
# Nearest to hit: reached, hits, promo, dp, grossing, costanza, boardgames, doraemon,
# Nearest to frac: constant, mgf, dt, ddot, corum, osten, left, vdash,
# Nearest to older: age, families, median, householder, someone, females, below, males,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8543 0.0759 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8667 0.0746 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8219 0.0752 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8490 0.0743 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8867 0.0750 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8544 0.0753 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9572 0.0742 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8812 0.0741 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9341 0.0738 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8400 0.0743 sec/batch
# Nearest to may: remaining, textured, april, usually, desecration, frozen, gregorian, june,
# Nearest to all: there, plus, of, remaining, multivectors, only, are, for,
# Nearest to there: all, are, only, every, hanifa, varro, of, converse,
# Nearest to history: see, historical, encyclopedia, zork, disambiguation, one, millennia, references,
# Nearest to by: the, of, in, and, as, for, which, an,
# Nearest to seven: four, nine, six, one, two, three, eight, five,
# Nearest to world: jerzy, exhibition, koestler, losers, unaids, factbook, premillennialism, sardines,
# Nearest to more: than, mostly, and, many, stronger, have, an, less,
# Nearest to mainly: followed, coaching, reconciliation, berber, doubling, magazines, operate, seeker,
# Nearest to http: www, htm, geocities, html, edu, org, php, shtml,
# Nearest to recorded: songs, compilation, recording, sow, tennant, records, hwv, housings,
# Nearest to notes: mcdougall, note, piccolo, macmillan, atwood, confusingly, malvinas, capella,
# Nearest to animals: animal, swarms, locust, guilbert, seductress, landholdings, tokugawa, cartier,
# Nearest to hit: reached, hits, costanza, promo, grossing, dp, septentrional, octopuses,
# Nearest to frac: constant, dt, mgf, ddot, corum, osten, relegating, left,
# Nearest to older: age, families, median, householder, someone, females, below, males,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8013 0.0759 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8605 0.0733 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7700 0.0718 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8875 0.0718 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8579 0.0721 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8466 0.0716 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9025 0.0353 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8249 0.0719 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8136 0.0724 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8361 0.0717 sec/batch
# Nearest to may: april, remaining, textured, usually, sedatives, on, gregorian, frozen,
# Nearest to all: there, plus, remaining, only, of, multivectors, in, are,
# Nearest to there: all, varro, exists, hanifa, converse, are, might, only,
# Nearest to history: see, historical, encyclopedia, disambiguation, millennia, zork, article, links,
# Nearest to by: the, of, in, and, for, as, an, thus,
# Nearest to seven: four, nine, six, one, three, two, eight, five,
# Nearest to world: jerzy, exhibition, koestler, losers, chancellery, premillennialism, history, unaids,
# Nearest to more: than, many, mostly, have, stronger, less, an, and,
# Nearest to mainly: berber, followed, reconciliation, coaching, operate, protestant, doubling, seeker,
# Nearest to http: www, htm, geocities, html, edu, org, php, shtml,
# Nearest to recorded: songs, compilation, tennant, recording, sow, stealth, hwv, snowstorms,
# Nearest to notes: mcdougall, note, piccolo, atwood, macmillan, malvinas, confusingly, putty,
# Nearest to animals: animal, locust, swarms, guilbert, landholdings, seductress, tokugawa, unforgettable,
# Nearest to hit: reached, hits, grossing, costanza, alerted, promo, septentrional, dp,
# Nearest to frac: constant, dt, mgf, ddot, corum, osten, vdash, relegating,
# Nearest to older: age, families, median, someone, householder, females, below, males,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7981 0.0735 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8330 0.0717 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8288 0.0716 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7743 0.0722 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8687 0.0715 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8164 0.0719 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8705 0.0722 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7910 0.0718 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8154 0.0716 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8174 0.0719 sec/batch
# Nearest to may: usually, remaining, textured, frozen, this, be, sedatives, april,
# Nearest to all: there, of, only, plus, are, multivectors, remaining, in,
# Nearest to there: all, only, exists, is, if, are, every, this,
# Nearest to history: see, historical, of, encyclopedia, disambiguation, the, article, one,
# Nearest to by: the, of, in, and, for, as, which, an,
# Nearest to seven: four, nine, six, one, three, two, eight, five,
# Nearest to world: exhibition, jerzy, history, losers, unaids, koestler, premillennialism, biographie,
# Nearest to more: than, many, and, of, have, an, mostly, as,
# Nearest to mainly: followed, coaching, operate, reconciliation, protestant, seeker, berber, sergey,
# Nearest to http: www, htm, geocities, html, edu, org, php, shtml,
# Nearest to recorded: songs, compilation, stealth, recording, sow, tennant, hwv, naturalization,
# Nearest to notes: mcdougall, note, piccolo, macmillan, atwood, malvinas, confusingly, capella,
# Nearest to animals: animal, swarms, locust, guilbert, tokugawa, landholdings, seductress, cartier,
# Nearest to hit: reached, hits, octopuses, run, costanza, dp, grossing, permitting,
# Nearest to frac: constant, dt, mgf, ddot, corum, vdash, osten, pleads,
# Nearest to older: age, families, median, someone, householder, below, females, males,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7736 0.0731 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8132 0.0719 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8774 0.0719 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8307 0.0718 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8129 0.0725 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9026 0.0725 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8448 0.0718 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8253 0.0721 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8168 0.0714 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8605 0.0716 sec/batch
# Nearest to may: textured, remaining, the, usually, this, april, or, for,
# Nearest to all: there, only, are, of, plus, multivectors, such, as,
# Nearest to there: all, only, are, if, exists, every, might, four,
# Nearest to history: see, historical, encyclopedia, disambiguation, of, zork, one, links,
# Nearest to by: the, of, and, as, for, in, an, which,
# Nearest to seven: four, nine, six, one, three, eight, two, five,
# Nearest to world: exhibition, jerzy, koestler, losers, unaids, biographie, history, premillennialism,
# Nearest to more: than, an, many, stronger, and, have, less, as,
# Nearest to mainly: protestant, reconciliation, magazines, coaching, followed, seeker, sr, operate,
# Nearest to http: www, htm, geocities, html, edu, org, php, shtml,
# Nearest to recorded: songs, recording, compilation, tennant, continued, billions, stealth, sow,
# Nearest to notes: mcdougall, note, piccolo, macmillan, atwood, malvinas, confusingly, capella,
# Nearest to animals: animal, swarms, locust, tokugawa, guilbert, landholdings, mesozoic, predators,
# Nearest to hit: reached, hits, costanza, dp, grossing, octopuses, pop, promo,
# Nearest to frac: constant, dt, mgf, ddot, corum, osten, left, right,
# Nearest to older: age, families, median, householder, someone, below, females, sizable,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8693 0.0727 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8398 0.0721 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8298 0.0717 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8742 0.0716 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8742 0.0721 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8432 0.0720 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8267 0.0719 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8564 0.0719 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8031 0.0722 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8002 0.0716 sec/batch
# Nearest to may: the, or, usually, and, to, for, on, textured,
# Nearest to all: there, only, are, of, multivectors, plus, as, remaining,
# Nearest to there: all, only, are, exists, might, four, varro, if,
# Nearest to history: see, historical, of, zork, encyclopedia, millennia, disambiguation, links,
# Nearest to by: the, of, in, and, as, for, an, which,
# Nearest to seven: four, nine, six, one, two, three, eight, five,
# Nearest to world: jerzy, exhibition, koestler, unaids, premillennialism, history, factbook, unanswered,
# Nearest to more: than, many, and, stronger, an, the, of, as,
# Nearest to mainly: coaching, reconciliation, followed, magazines, operate, seeker, berber, sr,
# Nearest to http: www, htm, geocities, html, edu, org, php, shtml,
# Nearest to recorded: songs, compilation, tennant, billions, naturalization, snowstorms, hwv, sow,
# Nearest to notes: mcdougall, note, piccolo, atwood, macmillan, malvinas, confusingly, capella,
# Nearest to animals: animal, swarms, tokugawa, locust, landholdings, guilbert, seductress, mesozoic,
# Nearest to hit: reached, hits, dp, costanza, yvonne, guessed, octopuses, skelter,
# Nearest to frac: constant, dt, mgf, ddot, corum, osten, load, vdash,
# Nearest to older: age, families, median, householder, below, females, someone, males,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8680 0.0731 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7980 0.0743 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9145 0.0745 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9176 0.0729 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8704 0.0735 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8496 0.0718 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7889 0.0721 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8166 0.0732 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7235 0.0749 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8744 0.0752 sec/batch
# Nearest to may: or, usually, the, remaining, april, textured, sedatives, gym,
# Nearest to all: there, of, are, only, plus, multivectors, remaining, morphisms,
# Nearest to there: all, are, might, if, is, only, exists, every,
# Nearest to history: see, historical, of, zork, disambiguation, links, the, encyclopedia,
# Nearest to by: the, of, in, and, for, as, an, many,
# Nearest to seven: four, nine, six, one, two, eight, three, five,
# Nearest to world: exhibition, jerzy, koestler, germany, proudest, premillennialism, losers, biographie,
# Nearest to more: than, as, many, and, of, mostly, the, an,
# Nearest to mainly: magazines, coaching, followed, berber, reconciliation, protestant, operate, doubling,
# Nearest to http: www, htm, html, geocities, edu, org, php, shtml,
# Nearest to recorded: songs, tennant, compilation, naturalization, billions, recording, hwv, snowstorms,
# Nearest to notes: mcdougall, note, piccolo, macmillan, atwood, malvinas, confusingly, putty,
# Nearest to animals: animal, swarms, tokugawa, seductress, locust, landholdings, guilbert, wolves,
# Nearest to hit: reached, hits, dp, costanza, yvonne, septentrional, guessed, hilversum,
# Nearest to frac: constant, dt, mgf, ddot, corum, osten, vdash, vec,
# Nearest to older: age, families, median, householder, below, someone, females, sizable,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8316 0.0759 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8102 0.0745 sec/batch
# total_elapsed_time -3488.752648115158

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
